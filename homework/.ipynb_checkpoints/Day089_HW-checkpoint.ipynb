# %% [markdown]
# ## Work
# 1. 請自行定義一個 loss function, 為 0.3 * focal loss + 0.7 cross-entropy，訓練並比較結果

# %%
import os
import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    """Code Here
    建立你的神經網路
    """
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 25
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
import tensorflow as tf
import keras.backend as K

def combined_loss(gamma=2., alpha=4., ce_weights=0.7, fcl_weights=0.3):
    gamma = float(gamma)
    alpha = float(alpha)
    def CE_focal_loss(y_true, y_pred):
        """Focal loss for multi-classification
        FL(p_t)=-alpha(1-p_t)^{gamma}ln(p_t)
        """
        epsilon = 1e-8
        y_true = tf.convert_to_tensor(y_true, tf.float32)
        y_pred = tf.convert_to_tensor(y_pred, tf.float32)

        model_out = tf.add(y_pred, epsilon)
        ce = tf.multiply(y_true, -tf.math.log(model_out))
        weight = tf.multiply(y_true, tf.pow(tf.subtract(1., model_out), gamma))
        fl = tf.multiply(alpha, tf.multiply(weight, ce))
        reduced_fl = tf.reduce_max(fl, axis=1)
        
        ce_loss = keras.losses.categorical_crossentropy(y_true, y_pred)
        return (ce_weights*ce_loss) + (fcl_weights*tf.reduce_mean(reduced_fl) )
    return CE_focal_loss

ce_weights_list = [0., 0.3, 0.5, 0.7, 1]

# %%
import itertools
results = {}

for i, ce_w in enumerate(ce_weights_list):
    print("Numbers of exp: %i, ce_weight: %.2f" % (i, ce_w))

    model = build_mlp(input_shape=x_train.shape[1:])
    model.summary()
    optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
    """Code Here
    將自定義的 loss function 加入模型
    """
    model.compile(loss=combined_loss(), metrics=["accuracy"], optimizer=optimizer)
    model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=BATCH_SIZE, 
              validation_data=(x_test, y_test), 
              shuffle=True
             )
    
    # Collect results
    exp_name_tag = ("exp-%s" % (i))
    results[exp_name_tag] = {'train-loss': model.history.history["loss"],
                             'valid-loss': model.history.history["val_loss"],
                             'train-acc': model.history.history["accuracy"],
                             'valid-acc': model.history.history["val_accuracy"]}
# Out:
# Numbers of exp: 0, ce_weight: 0.00
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 16s 328us/step - loss: 3.4542 - accuracy: 0.2943 - val_loss: 3.5580 - val_accuracy: 0.1795
# Epoch 2/25
# 50000/50000 [==============================] - 11s 225us/step - loss: 2.5741 - accuracy: 0.4182 - val_loss: 3.1785 - val_accuracy: 0.2830
# Epoch 3/25
# 50000/50000 [==============================] - 15s 293us/step - loss: 2.3597 - accuracy: 0.4582 - val_loss: 2.7798 - val_accuracy: 0.3785
# Epoch 4/25
# 50000/50000 [==============================] - 12s 246us/step - loss: 2.2278 - accuracy: 0.4855 - val_loss: 2.5786 - val_accuracy: 0.4169
# Epoch 5/25
# 50000/50000 [==============================] - 11s 218us/step - loss: 2.1250 - accuracy: 0.5061 - val_loss: 2.4257 - val_accuracy: 0.4425
# Epoch 6/25
# 50000/50000 [==============================] - 12s 234us/step - loss: 2.0421 - accuracy: 0.5208 - val_loss: 2.3527 - val_accuracy: 0.4537
# Epoch 7/25
# 50000/50000 [==============================] - 12s 244us/step - loss: 1.9682 - accuracy: 0.5367 - val_loss: 2.2787 - val_accuracy: 0.4658
# Epoch 8/25
# 50000/50000 [==============================] - 13s 265us/step - loss: 1.8989 - accuracy: 0.5518 - val_loss: 2.2455 - val_accuracy: 0.4683
# Epoch 9/25
# 50000/50000 [==============================] - 11s 222us/step - loss: 1.8316 - accuracy: 0.5639 - val_loss: 2.2488 - val_accuracy: 0.4701
# Epoch 10/25
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.7760 - accuracy: 0.5776 - val_loss: 2.2210 - val_accuracy: 0.4748
# Epoch 11/25
# 50000/50000 [==============================] - 12s 240us/step - loss: 1.7221 - accuracy: 0.5891 - val_loss: 2.2108 - val_accuracy: 0.4833
# Epoch 12/25
# 50000/50000 [==============================] - 13s 265us/step - loss: 1.6652 - accuracy: 0.6008 - val_loss: 2.2159 - val_accuracy: 0.4795
# Epoch 13/25
# 50000/50000 [==============================] - 12s 249us/step - loss: 1.6072 - accuracy: 0.6160 - val_loss: 2.1989 - val_accuracy: 0.4859
# Epoch 14/25
# 50000/50000 [==============================] - 13s 256us/step - loss: 1.5582 - accuracy: 0.6250 - val_loss: 2.2360 - val_accuracy: 0.4782
# Epoch 15/25
# 50000/50000 [==============================] - 13s 261us/step - loss: 1.5094 - accuracy: 0.6351 - val_loss: 2.2129 - val_accuracy: 0.4888
# Epoch 16/25
# 50000/50000 [==============================] - 13s 255us/step - loss: 1.4589 - accuracy: 0.6472 - val_loss: 2.2113 - val_accuracy: 0.4857
# Epoch 17/25
# 50000/50000 [==============================] - 11s 215us/step - loss: 1.4103 - accuracy: 0.6596 - val_loss: 2.1990 - val_accuracy: 0.4923
# Epoch 18/25
# 50000/50000 [==============================] - 10s 206us/step - loss: 1.3630 - accuracy: 0.6716 - val_loss: 2.2381 - val_accuracy: 0.4847
# Epoch 19/25
# 50000/50000 [==============================] - 13s 250us/step - loss: 1.3176 - accuracy: 0.6804 - val_loss: 2.2103 - val_accuracy: 0.4879
# Epoch 20/25
# 50000/50000 [==============================] - 13s 256us/step - loss: 1.2720 - accuracy: 0.6932 - val_loss: 2.2524 - val_accuracy: 0.4929
# Epoch 21/25
# 50000/50000 [==============================] - 11s 227us/step - loss: 1.2250 - accuracy: 0.7038 - val_loss: 2.2308 - val_accuracy: 0.4921
# Epoch 22/25
# 50000/50000 [==============================] - 11s 212us/step - loss: 1.1832 - accuracy: 0.7144 - val_loss: 2.2779 - val_accuracy: 0.4857
# Epoch 23/25
# 50000/50000 [==============================] - 11s 222us/step - loss: 1.1381 - accuracy: 0.7259 - val_loss: 2.2646 - val_accuracy: 0.4934
# Epoch 24/25
# 50000/50000 [==============================] - 11s 219us/step - loss: 1.0991 - accuracy: 0.7352 - val_loss: 2.3450 - val_accuracy: 0.4825
# Epoch 25/25
# 50000/50000 [==============================] - 11s 221us/step - loss: 1.0575 - accuracy: 0.7461 - val_loss: 2.2974 - val_accuracy: 0.4842
# Numbers of exp: 1, ce_weight: 0.30
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 15s 299us/step - loss: 3.4461 - accuracy: 0.2986 - val_loss: 3.6041 - val_accuracy: 0.1608
# Epoch 2/25
# 50000/50000 [==============================] - 11s 217us/step - loss: 2.5980 - accuracy: 0.4147 - val_loss: 3.0211 - val_accuracy: 0.3375
# Epoch 3/25
# 50000/50000 [==============================] - 10s 207us/step - loss: 2.3801 - accuracy: 0.4563 - val_loss: 2.7389 - val_accuracy: 0.3916
# Epoch 4/25
# 50000/50000 [==============================] - 11s 222us/step - loss: 2.2483 - accuracy: 0.4805 - val_loss: 2.5924 - val_accuracy: 0.4264
# Epoch 5/25
# 50000/50000 [==============================] - 11s 220us/step - loss: 2.1465 - accuracy: 0.5014 - val_loss: 2.4003 - val_accuracy: 0.4500
# Epoch 6/25
# 50000/50000 [==============================] - 11s 212us/step - loss: 2.0620 - accuracy: 0.5188 - val_loss: 2.3317 - val_accuracy: 0.4568
# Epoch 7/25
# 50000/50000 [==============================] - 11s 213us/step - loss: 1.9837 - accuracy: 0.5339 - val_loss: 2.2946 - val_accuracy: 0.4707
# Epoch 8/25
# 50000/50000 [==============================] - 11s 213us/step - loss: 1.9156 - accuracy: 0.5479 - val_loss: 2.2568 - val_accuracy: 0.4711
# Epoch 9/25
# 50000/50000 [==============================] - 11s 221us/step - loss: 1.8520 - accuracy: 0.5628 - val_loss: 2.2409 - val_accuracy: 0.4800
# Epoch 10/25
# 50000/50000 [==============================] - 12s 242us/step - loss: 1.7892 - accuracy: 0.5750 - val_loss: 2.2246 - val_accuracy: 0.4819
# Epoch 11/25
# 50000/50000 [==============================] - 12s 241us/step - loss: 1.7297 - accuracy: 0.5890 - val_loss: 2.2108 - val_accuracy: 0.4841
# Epoch 12/25
# 50000/50000 [==============================] - 12s 240us/step - loss: 1.6756 - accuracy: 0.6005 - val_loss: 2.1898 - val_accuracy: 0.4961
# Epoch 13/25
# 50000/50000 [==============================] - 12s 245us/step - loss: 1.6247 - accuracy: 0.6123 - val_loss: 2.1795 - val_accuracy: 0.4918
# Epoch 14/25
# 50000/50000 [==============================] - 13s 253us/step - loss: 1.5712 - accuracy: 0.6224 - val_loss: 2.2463 - val_accuracy: 0.4878
# Epoch 15/25
# 50000/50000 [==============================] - 12s 240us/step - loss: 1.5247 - accuracy: 0.6351 - val_loss: 2.2158 - val_accuracy: 0.4916
# Epoch 16/25
# 50000/50000 [==============================] - 12s 240us/step - loss: 1.4702 - accuracy: 0.6457 - val_loss: 2.2000 - val_accuracy: 0.4991
# Epoch 17/25
# 50000/50000 [==============================] - 12s 234us/step - loss: 1.4240 - accuracy: 0.6584 - val_loss: 2.1942 - val_accuracy: 0.5008
# Epoch 18/25
# 50000/50000 [==============================] - 12s 238us/step - loss: 1.3738 - accuracy: 0.6695 - val_loss: 2.2024 - val_accuracy: 0.5010
# Epoch 19/25
# 50000/50000 [==============================] - 12s 244us/step - loss: 1.3265 - accuracy: 0.6812 - val_loss: 2.2280 - val_accuracy: 0.4930
# Epoch 20/25
# 50000/50000 [==============================] - 12s 248us/step - loss: 1.2834 - accuracy: 0.6909 - val_loss: 2.2409 - val_accuracy: 0.4965
# Epoch 21/25
# 50000/50000 [==============================] - 12s 244us/step - loss: 1.2401 - accuracy: 0.7018 - val_loss: 2.2549 - val_accuracy: 0.4919
# Epoch 22/25
# 50000/50000 [==============================] - 12s 249us/step - loss: 1.1919 - accuracy: 0.7143 - val_loss: 2.2760 - val_accuracy: 0.4893
# Epoch 23/25
# 50000/50000 [==============================] - 12s 236us/step - loss: 1.1502 - accuracy: 0.7244 - val_loss: 2.2665 - val_accuracy: 0.4937
# Epoch 24/25
# 50000/50000 [==============================] - 12s 242us/step - loss: 1.1088 - accuracy: 0.7347 - val_loss: 2.2856 - val_accuracy: 0.4919
# Epoch 25/25
# 50000/50000 [==============================] - 12s 246us/step - loss: 1.0601 - accuracy: 0.7457 - val_loss: 2.2994 - val_accuracy: 0.4882
# Numbers of exp: 2, ce_weight: 0.50
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 14s 274us/step - loss: 3.4281 - accuracy: 0.3097 - val_loss: 3.4070 - val_accuracy: 0.2392
# Epoch 2/25
# 50000/50000 [==============================] - 12s 245us/step - loss: 2.5503 - accuracy: 0.4235 - val_loss: 3.1201 - val_accuracy: 0.2784
# Epoch 3/25
# 50000/50000 [==============================] - 12s 247us/step - loss: 2.3427 - accuracy: 0.4629 - val_loss: 2.7700 - val_accuracy: 0.3743
# Epoch 4/25
# 50000/50000 [==============================] - 12s 245us/step - loss: 2.2155 - accuracy: 0.4901 - val_loss: 2.5862 - val_accuracy: 0.4124
# Epoch 5/25
# 50000/50000 [==============================] - 12s 243us/step - loss: 2.1155 - accuracy: 0.5096 - val_loss: 2.4842 - val_accuracy: 0.4230
# Epoch 6/25
# 50000/50000 [==============================] - 12s 249us/step - loss: 2.0310 - accuracy: 0.5280 - val_loss: 2.3662 - val_accuracy: 0.4450
# Epoch 7/25
# 50000/50000 [==============================] - 12s 242us/step - loss: 1.9543 - accuracy: 0.5438 - val_loss: 2.3042 - val_accuracy: 0.4605
# Epoch 8/25
# 50000/50000 [==============================] - 12s 242us/step - loss: 1.8840 - accuracy: 0.5574 - val_loss: 2.2425 - val_accuracy: 0.4750
# Epoch 9/25
# 50000/50000 [==============================] - 12s 246us/step - loss: 1.8243 - accuracy: 0.5709 - val_loss: 2.2400 - val_accuracy: 0.4724
# Epoch 10/25
# 50000/50000 [==============================] - 12s 248us/step - loss: 1.7636 - accuracy: 0.5845 - val_loss: 2.2388 - val_accuracy: 0.4717
# Epoch 11/25
# 50000/50000 [==============================] - 13s 258us/step - loss: 1.7039 - accuracy: 0.5962 - val_loss: 2.2385 - val_accuracy: 0.4833
# Epoch 12/25
# 50000/50000 [==============================] - 13s 258us/step - loss: 1.6457 - accuracy: 0.6088 - val_loss: 2.2493 - val_accuracy: 0.4759
# Epoch 13/25
# 50000/50000 [==============================] - 12s 250us/step - loss: 1.5932 - accuracy: 0.6211 - val_loss: 2.2074 - val_accuracy: 0.4852
# Epoch 14/25
# 50000/50000 [==============================] - 13s 255us/step - loss: 1.5446 - accuracy: 0.6328 - val_loss: 2.2097 - val_accuracy: 0.4812
# Epoch 15/25
# 50000/50000 [==============================] - 12s 249us/step - loss: 1.4925 - accuracy: 0.6434 - val_loss: 2.2430 - val_accuracy: 0.4825
# Epoch 16/25
# 50000/50000 [==============================] - 13s 250us/step - loss: 1.4443 - accuracy: 0.6551 - val_loss: 2.2187 - val_accuracy: 0.4844
# Epoch 17/25
# 50000/50000 [==============================] - 13s 256us/step - loss: 1.3923 - accuracy: 0.6657 - val_loss: 2.2083 - val_accuracy: 0.4952
# Epoch 18/25
# 50000/50000 [==============================] - 12s 241us/step - loss: 1.3422 - accuracy: 0.6772 - val_loss: 2.2296 - val_accuracy: 0.4834
# Epoch 19/25
# 50000/50000 [==============================] - 11s 226us/step - loss: 1.3000 - accuracy: 0.6875 - val_loss: 2.2710 - val_accuracy: 0.4833
# Epoch 20/25
# 50000/50000 [==============================] - 12s 250us/step - loss: 1.2568 - accuracy: 0.6973 - val_loss: 2.2918 - val_accuracy: 0.4790
# Epoch 21/25
# 50000/50000 [==============================] - 14s 278us/step - loss: 1.2101 - accuracy: 0.7083 - val_loss: 2.3186 - val_accuracy: 0.4828
# Epoch 22/25
# 50000/50000 [==============================] - 13s 257us/step - loss: 1.1672 - accuracy: 0.7183 - val_loss: 2.2631 - val_accuracy: 0.4910
# Epoch 23/25
# 50000/50000 [==============================] - 12s 236us/step - loss: 1.1188 - accuracy: 0.7304 - val_loss: 2.2907 - val_accuracy: 0.4902
# Epoch 24/25
# 50000/50000 [==============================] - 12s 245us/step - loss: 1.0739 - accuracy: 0.7420 - val_loss: 2.3396 - val_accuracy: 0.4922
# Epoch 25/25
# 50000/50000 [==============================] - 12s 240us/step - loss: 1.0297 - accuracy: 0.7526 - val_loss: 2.2880 - val_accuracy: 0.4955
# Numbers of exp: 3, ce_weight: 0.70
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 15s 299us/step - loss: 3.4215 - accuracy: 0.3038 - val_loss: 3.5293 - val_accuracy: 0.1812
# Epoch 2/25
# 50000/50000 [==============================] - 10s 202us/step - loss: 2.5570 - accuracy: 0.4203 - val_loss: 3.0442 - val_accuracy: 0.3194
# Epoch 3/25
# 50000/50000 [==============================] - 11s 218us/step - loss: 2.3556 - accuracy: 0.4601 - val_loss: 2.7693 - val_accuracy: 0.3847
# Epoch 4/25
# 50000/50000 [==============================] - 10s 199us/step - loss: 2.2302 - accuracy: 0.4836 - val_loss: 2.5539 - val_accuracy: 0.4196
# Epoch 5/25
# 50000/50000 [==============================] - 10s 200us/step - loss: 2.1357 - accuracy: 0.5027 - val_loss: 2.4468 - val_accuracy: 0.4371
# Epoch 6/25
# 50000/50000 [==============================] - 10s 207us/step - loss: 2.0558 - accuracy: 0.5190 - val_loss: 2.3389 - val_accuracy: 0.4594
# Epoch 7/25
# 50000/50000 [==============================] - 11s 219us/step - loss: 1.9831 - accuracy: 0.5349 - val_loss: 2.3148 - val_accuracy: 0.4626
# Epoch 8/25
# 50000/50000 [==============================] - 11s 213us/step - loss: 1.9157 - accuracy: 0.5484 - val_loss: 2.2650 - val_accuracy: 0.4731
# Epoch 9/25
# 50000/50000 [==============================] - 10s 203us/step - loss: 1.8506 - accuracy: 0.5639 - val_loss: 2.2421 - val_accuracy: 0.4786
# Epoch 10/25
# 50000/50000 [==============================] - 11s 223us/step - loss: 1.7932 - accuracy: 0.5744 - val_loss: 2.2317 - val_accuracy: 0.4786
# Epoch 11/25
# 50000/50000 [==============================] - 13s 250us/step - loss: 1.7396 - accuracy: 0.5889 - val_loss: 2.2006 - val_accuracy: 0.4912
# Epoch 12/25
# 50000/50000 [==============================] - 11s 222us/step - loss: 1.6836 - accuracy: 0.5995 - val_loss: 2.2141 - val_accuracy: 0.4869
# Epoch 13/25
# 50000/50000 [==============================] - 11s 224us/step - loss: 1.6292 - accuracy: 0.6105 - val_loss: 2.2092 - val_accuracy: 0.4887
# Epoch 14/25
# 50000/50000 [==============================] - 11s 220us/step - loss: 1.5811 - accuracy: 0.6224 - val_loss: 2.2012 - val_accuracy: 0.4863
# Epoch 15/25
# 50000/50000 [==============================] - 11s 222us/step - loss: 1.5303 - accuracy: 0.6349 - val_loss: 2.2211 - val_accuracy: 0.4868
# Epoch 16/25
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.4818 - accuracy: 0.6455 - val_loss: 2.1968 - val_accuracy: 0.4939
# Epoch 17/25
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.4342 - accuracy: 0.6554 - val_loss: 2.1998 - val_accuracy: 0.4980
# Epoch 18/25
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.3858 - accuracy: 0.6669 - val_loss: 2.2548 - val_accuracy: 0.4867
# Epoch 19/25
# 50000/50000 [==============================] - 13s 263us/step - loss: 1.3396 - accuracy: 0.6771 - val_loss: 2.2167 - val_accuracy: 0.4906
# Epoch 20/25
# 50000/50000 [==============================] - 12s 243us/step - loss: 1.2957 - accuracy: 0.6882 - val_loss: 2.2449 - val_accuracy: 0.4926
# Epoch 21/25
# 50000/50000 [==============================] - 12s 248us/step - loss: 1.2487 - accuracy: 0.7012 - val_loss: 2.2152 - val_accuracy: 0.4979
# Epoch 22/25
# 50000/50000 [==============================] - 13s 261us/step - loss: 1.2027 - accuracy: 0.7103 - val_loss: 2.2368 - val_accuracy: 0.4961
# Epoch 23/25
# 50000/50000 [==============================] - 12s 242us/step - loss: 1.1603 - accuracy: 0.7201 - val_loss: 2.2474 - val_accuracy: 0.4953
# Epoch 24/25
# 50000/50000 [==============================] - 12s 246us/step - loss: 1.1191 - accuracy: 0.7302 - val_loss: 2.2910 - val_accuracy: 0.4941
# Epoch 25/25
# 50000/50000 [==============================] - 10s 210us/step - loss: 1.0791 - accuracy: 0.7415 - val_loss: 2.2914 - val_accuracy: 0.4910
# Numbers of exp: 4, ce_weight: 1.00
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 12s 234us/step - loss: 3.4116 - accuracy: 0.2994 - val_loss: 3.6072 - val_accuracy: 0.1674
# Epoch 2/25
# 50000/50000 [==============================] - 10s 204us/step - loss: 2.5807 - accuracy: 0.4163 - val_loss: 3.1015 - val_accuracy: 0.2882
# Epoch 3/25
# 50000/50000 [==============================] - 10s 205us/step - loss: 2.3713 - accuracy: 0.4582 - val_loss: 2.8169 - val_accuracy: 0.3670
# Epoch 4/25
# 50000/50000 [==============================] - 10s 205us/step - loss: 2.2377 - accuracy: 0.4831 - val_loss: 2.5973 - val_accuracy: 0.4084
# Epoch 5/25
# 50000/50000 [==============================] - 10s 206us/step - loss: 2.1407 - accuracy: 0.5043 - val_loss: 2.4378 - val_accuracy: 0.4404
# Epoch 6/25
# 50000/50000 [==============================] - 10s 205us/step - loss: 2.0550 - accuracy: 0.5217 - val_loss: 2.3535 - val_accuracy: 0.4506
# Epoch 7/25
# 50000/50000 [==============================] - 10s 205us/step - loss: 1.9797 - accuracy: 0.5371 - val_loss: 2.3154 - val_accuracy: 0.4601
# Epoch 8/25
# 50000/50000 [==============================] - 10s 208us/step - loss: 1.9160 - accuracy: 0.5507 - val_loss: 2.3064 - val_accuracy: 0.4570
# Epoch 9/25
# 50000/50000 [==============================] - 11s 213us/step - loss: 1.8527 - accuracy: 0.5652 - val_loss: 2.2895 - val_accuracy: 0.4613
# Epoch 10/25
# 50000/50000 [==============================] - 10s 205us/step - loss: 1.7987 - accuracy: 0.5749 - val_loss: 2.2248 - val_accuracy: 0.4846
# Epoch 11/25
# 50000/50000 [==============================] - 10s 209us/step - loss: 1.7432 - accuracy: 0.5879 - val_loss: 2.2262 - val_accuracy: 0.4752
# Epoch 12/25
# 50000/50000 [==============================] - 10s 209us/step - loss: 1.6849 - accuracy: 0.6007 - val_loss: 2.2373 - val_accuracy: 0.4751
# Epoch 13/25
# 50000/50000 [==============================] - 11s 214us/step - loss: 1.6362 - accuracy: 0.6101 - val_loss: 2.2389 - val_accuracy: 0.4743
# Epoch 14/25
# 50000/50000 [==============================] - 12s 234us/step - loss: 1.5882 - accuracy: 0.6225 - val_loss: 2.2119 - val_accuracy: 0.4866
# Epoch 15/25
# 50000/50000 [==============================] - 10s 208us/step - loss: 1.5333 - accuracy: 0.6352 - val_loss: 2.2113 - val_accuracy: 0.4847
# Epoch 16/25
# 50000/50000 [==============================] - 11s 212us/step - loss: 1.4876 - accuracy: 0.6452 - val_loss: 2.2376 - val_accuracy: 0.4827
# Epoch 17/25
# 50000/50000 [==============================] - 12s 232us/step - loss: 1.4397 - accuracy: 0.6577 - val_loss: 2.2480 - val_accuracy: 0.4841
# Epoch 18/25
# 50000/50000 [==============================] - 12s 244us/step - loss: 1.3944 - accuracy: 0.6664 - val_loss: 2.2538 - val_accuracy: 0.4863
# Epoch 19/25
# 50000/50000 [==============================] - 12s 242us/step - loss: 1.3456 - accuracy: 0.6781 - val_loss: 2.2685 - val_accuracy: 0.4832
# Epoch 20/25
# 50000/50000 [==============================] - 12s 244us/step - loss: 1.2979 - accuracy: 0.6890 - val_loss: 2.2991 - val_accuracy: 0.4803
# Epoch 21/25
# 50000/50000 [==============================] - 11s 210us/step - loss: 1.2578 - accuracy: 0.6991 - val_loss: 2.2862 - val_accuracy: 0.4829
# Epoch 22/25
# 50000/50000 [==============================] - 11s 221us/step - loss: 1.2120 - accuracy: 0.7112 - val_loss: 2.2800 - val_accuracy: 0.4917
# Epoch 23/25
# 50000/50000 [==============================] - 10s 207us/step - loss: 1.1685 - accuracy: 0.7204 - val_loss: 2.2949 - val_accuracy: 0.4917
# Epoch 24/25
# 50000/50000 [==============================] - 10s 198us/step - loss: 1.1233 - accuracy: 0.7309 - val_loss: 2.2919 - val_accuracy: 0.4871
# Epoch 25/25
# 50000/50000 [==============================] - 11s 221us/step - loss: 1.0788 - accuracy: 0.7414 - val_loss: 2.3191 - val_accuracy: 0.4854

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as mplcm
import matplotlib.colors as colors
# %matplotlib inline
NUM_COLORS = len(results.keys())

cm = plt.get_cmap('gist_rainbow')
cNorm  = colors.Normalize(vmin=0, vmax=NUM_COLORS-1)
scalarMap = mplcm.ScalarMappable(norm=cNorm, cmap=cm)
color_bar = [scalarMap.to_rgba(i) for i in range(NUM_COLORS)]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()
