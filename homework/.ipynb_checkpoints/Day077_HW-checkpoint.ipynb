# %% [markdown]
# ## Work
# 1. 請將 Epoch 加到 500 個，並觀察 learning curve 的走勢
# 2. 請將 Optimizer 換成 SGD，並觀察 learning curve 的走勢

# %%
import os
import keras

# 本作業可以不需使用 GPU, 將 GPU 設定為 "無" (若有 GPU 且想開啟，可設為 "0")
os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# Using TensorFlow backend.

# %%
# 從 Keras 的內建功能中，取得 train 與 test 資料集
train, test = keras.datasets.cifar10.load_data()

# %%
# 將 X 與 Y 獨立放進變數
x_train, y_train = train
x_test, y_test = test
# 資料前處理 - 標準化
x_train = x_train / 255.
x_test = x_test / 255.

# 將資料從圖形 (RGB) 轉為向量 (Single Vector)
x_train = x_train.reshape((len(x_train), -1))
x_test = x_test.reshape((len(x_test), -1))

# 將目標轉為 one-hot encoding
y_train = keras.utils.to_categorical(y_train, num_classes=10)
y_test = keras.utils.to_categorical(y_test, num_classes=10)

# %%
def build_mlp():
    """Code Here
    建立你的神經網路
    """
    input_layer = keras.layers.Input([x_train.shape[-1]])
    x = keras.layers.Dense(units=512, activation="relu")(input_layer)
    x = keras.layers.Dense(units=256, activation="relu")(x)
    x = keras.layers.Dense(units=128, activation="relu")(x)
    out = keras.layers.Dense(units=10, activation="softmax")(x)
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
"""
Compile 模型
"""
model = build_mlp()
# 用 Keras 內建方法檢視模型各層參數量
model.summary()

optimizer = keras.optimizers.Adam(lr=0.001)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1573376
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________

# %%
"""
設定要訓練的 Epoch 數
"""
model.fit(x_train, y_train, 
          epochs=100, 
          batch_size=256, 
          validation_data=(x_test, y_test), 
          shuffle=True)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 81s 2ms/step - loss: 1.9371 - accuracy: 0.2989 - val_loss: 1.7644 - val_accuracy: 0.3708
# Epoch 2/100
# 50000/50000 [==============================] - 17s 336us/step - loss: 1.7104 - accuracy: 0.3878 - val_loss: 1.6707 - val_accuracy: 0.3977
# Epoch 3/100
# 50000/50000 [==============================] - 17s 338us/step - loss: 1.6136 - accuracy: 0.4263 - val_loss: 1.5499 - val_accuracy: 0.4531
# Epoch 4/100
# 50000/50000 [==============================] - 17s 337us/step - loss: 1.5528 - accuracy: 0.4468 - val_loss: 1.5612 - val_accuracy: 0.4406
# Epoch 5/100
# 50000/50000 [==============================] - 17s 337us/step - loss: 1.5115 - accuracy: 0.4630 - val_loss: 1.4783 - val_accuracy: 0.4738
# Epoch 6/100
# 50000/50000 [==============================] - 17s 338us/step - loss: 1.4688 - accuracy: 0.4760 - val_loss: 1.4921 - val_accuracy: 0.4683
# Epoch 7/100
# 50000/50000 [==============================] - 17s 339us/step - loss: 1.4344 - accuracy: 0.4913 - val_loss: 1.4537 - val_accuracy: 0.4817
# Epoch 8/100
# 50000/50000 [==============================] - 17s 347us/step - loss: 1.4073 - accuracy: 0.5007 - val_loss: 1.4544 - val_accuracy: 0.4847
# Epoch 9/100
# 50000/50000 [==============================] - 18s 351us/step - loss: 1.3743 - accuracy: 0.5098 - val_loss: 1.4178 - val_accuracy: 0.4977
# Epoch 10/100
# 50000/50000 [==============================] - 17s 350us/step - loss: 1.3462 - accuracy: 0.5217 - val_loss: 1.4502 - val_accuracy: 0.4876
# Epoch 11/100
# 50000/50000 [==============================] - 18s 354us/step - loss: 1.3171 - accuracy: 0.5312 - val_loss: 1.3885 - val_accuracy: 0.5070
# Epoch 12/100
# 50000/50000 [==============================] - 17s 344us/step - loss: 1.2944 - accuracy: 0.5407 - val_loss: 1.3799 - val_accuracy: 0.5175
# Epoch 13/100
# 50000/50000 [==============================] - 17s 343us/step - loss: 1.2766 - accuracy: 0.5453 - val_loss: 1.3902 - val_accuracy: 0.5087
# Epoch 14/100
# 50000/50000 [==============================] - 17s 343us/step - loss: 1.2482 - accuracy: 0.5527 - val_loss: 1.4180 - val_accuracy: 0.4924
# Epoch 15/100
# 50000/50000 [==============================] - 17s 345us/step - loss: 1.2273 - accuracy: 0.5637 - val_loss: 1.4475 - val_accuracy: 0.4952
# Epoch 16/100
# 50000/50000 [==============================] - 17s 342us/step - loss: 1.2038 - accuracy: 0.5739 - val_loss: 1.3713 - val_accuracy: 0.5233
# Epoch 17/100
# 50000/50000 [==============================] - 17s 343us/step - loss: 1.1901 - accuracy: 0.5785 - val_loss: 1.3662 - val_accuracy: 0.5183
# Epoch 18/100
# 50000/50000 [==============================] - 18s 354us/step - loss: 1.1632 - accuracy: 0.5846 - val_loss: 1.3910 - val_accuracy: 0.5142
# Epoch 19/100
# 50000/50000 [==============================] - 18s 354us/step - loss: 1.1452 - accuracy: 0.5901 - val_loss: 1.3489 - val_accuracy: 0.5338
# Epoch 20/100
# 50000/50000 [==============================] - 17s 346us/step - loss: 1.1310 - accuracy: 0.5993 - val_loss: 1.3629 - val_accuracy: 0.5249
# Epoch 21/100
# 50000/50000 [==============================] - 17s 346us/step - loss: 1.1093 - accuracy: 0.6051 - val_loss: 1.3789 - val_accuracy: 0.5156
# Epoch 22/100
# 50000/50000 [==============================] - 17s 347us/step - loss: 1.0877 - accuracy: 0.6111 - val_loss: 1.3691 - val_accuracy: 0.5244
# Epoch 23/100
# 50000/50000 [==============================] - 17s 342us/step - loss: 1.0613 - accuracy: 0.6216 - val_loss: 1.3783 - val_accuracy: 0.5262
# Epoch 24/100
# 50000/50000 [==============================] - 17s 345us/step - loss: 1.0535 - accuracy: 0.6232 - val_loss: 1.3804 - val_accuracy: 0.5241
# Epoch 25/100
# 50000/50000 [==============================] - 17s 341us/step - loss: 1.0401 - accuracy: 0.6326 - val_loss: 1.3625 - val_accuracy: 0.5295
# Epoch 26/100
# 50000/50000 [==============================] - 17s 341us/step - loss: 1.0051 - accuracy: 0.6422 - val_loss: 1.3715 - val_accuracy: 0.5283
# Epoch 27/100
# 50000/50000 [==============================] - 17s 347us/step - loss: 1.0003 - accuracy: 0.6446 - val_loss: 1.3884 - val_accuracy: 0.5353
# Epoch 28/100
# 50000/50000 [==============================] - 17s 341us/step - loss: 0.9788 - accuracy: 0.6511 - val_loss: 1.4360 - val_accuracy: 0.5207
# Epoch 29/100
# 50000/50000 [==============================] - 17s 349us/step - loss: 0.9532 - accuracy: 0.6605 - val_loss: 1.4421 - val_accuracy: 0.5258
# Epoch 30/100
# 50000/50000 [==============================] - 17s 343us/step - loss: 0.9333 - accuracy: 0.6696 - val_loss: 1.4001 - val_accuracy: 0.5383
# Epoch 31/100
# 50000/50000 [==============================] - 17s 344us/step - loss: 0.9257 - accuracy: 0.6701 - val_loss: 1.4556 - val_accuracy: 0.5218
# Epoch 32/100
# 50000/50000 [==============================] - 17s 343us/step - loss: 0.9024 - accuracy: 0.6804 - val_loss: 1.4699 - val_accuracy: 0.5294
# Epoch 33/100
# 50000/50000 [==============================] - 17s 345us/step - loss: 0.8909 - accuracy: 0.6817 - val_loss: 1.4828 - val_accuracy: 0.5229
# Epoch 34/100
# 50000/50000 [==============================] - 17s 345us/step - loss: 0.8689 - accuracy: 0.6915 - val_loss: 1.5184 - val_accuracy: 0.5223
# Epoch 35/100
# 50000/50000 [==============================] - 17s 346us/step - loss: 0.8596 - accuracy: 0.6952 - val_loss: 1.4875 - val_accuracy: 0.5296
# Epoch 36/100
# 50000/50000 [==============================] - 17s 345us/step - loss: 0.8363 - accuracy: 0.7030 - val_loss: 1.5478 - val_accuracy: 0.5177
# Epoch 37/100
# 50000/50000 [==============================] - 17s 341us/step - loss: 0.8313 - accuracy: 0.7034 - val_loss: 1.5245 - val_accuracy: 0.5278
# Epoch 38/100
# 50000/50000 [==============================] - 17s 348us/step - loss: 0.8053 - accuracy: 0.7143 - val_loss: 1.5871 - val_accuracy: 0.5249
# Epoch 39/100
# 50000/50000 [==============================] - 17s 345us/step - loss: 0.7907 - accuracy: 0.7163 - val_loss: 1.5999 - val_accuracy: 0.5101
# Epoch 40/100
# 50000/50000 [==============================] - 17s 345us/step - loss: 0.7789 - accuracy: 0.7223 - val_loss: 1.6114 - val_accuracy: 0.5173
# Epoch 41/100
# 50000/50000 [==============================] - 17s 344us/step - loss: 0.7738 - accuracy: 0.7238 - val_loss: 1.5903 - val_accuracy: 0.5228
# Epoch 42/100
# 50000/50000 [==============================] - 17s 345us/step - loss: 0.7516 - accuracy: 0.7319 - val_loss: 1.6074 - val_accuracy: 0.5192
# Epoch 43/100
# 50000/50000 [==============================] - 17s 349us/step - loss: 0.7277 - accuracy: 0.7401 - val_loss: 1.6315 - val_accuracy: 0.5222
# Epoch 44/100
# 50000/50000 [==============================] - 18s 351us/step - loss: 0.7167 - accuracy: 0.7468 - val_loss: 1.6740 - val_accuracy: 0.5244
# Epoch 45/100
# 50000/50000 [==============================] - 17s 346us/step - loss: 0.7000 - accuracy: 0.7492 - val_loss: 1.7237 - val_accuracy: 0.5231
# Epoch 46/100
# 50000/50000 [==============================] - 18s 356us/step - loss: 0.6970 - accuracy: 0.7501 - val_loss: 1.7216 - val_accuracy: 0.5187
# Epoch 47/100
# 50000/50000 [==============================] - 17s 343us/step - loss: 0.6816 - accuracy: 0.7565 - val_loss: 1.7131 - val_accuracy: 0.5242
# Epoch 48/100
# 50000/50000 [==============================] - 17s 335us/step - loss: 0.6667 - accuracy: 0.7633 - val_loss: 1.7599 - val_accuracy: 0.5145
# Epoch 49/100
# 50000/50000 [==============================] - 17s 334us/step - loss: 0.6516 - accuracy: 0.7678 - val_loss: 1.8377 - val_accuracy: 0.5138
# Epoch 50/100
# 50000/50000 [==============================] - 16s 328us/step - loss: 0.6457 - accuracy: 0.7685 - val_loss: 1.8429 - val_accuracy: 0.5163
# Epoch 51/100
# 50000/50000 [==============================] - 16s 328us/step - loss: 0.6319 - accuracy: 0.7744 - val_loss: 1.8148 - val_accuracy: 0.5202
# Epoch 52/100
# 50000/50000 [==============================] - 17s 331us/step - loss: 0.6151 - accuracy: 0.7781 - val_loss: 1.9203 - val_accuracy: 0.5086
# Epoch 53/100
# 50000/50000 [==============================] - 16s 324us/step - loss: 0.6101 - accuracy: 0.7802 - val_loss: 1.9468 - val_accuracy: 0.5181
# Epoch 54/100
# 50000/50000 [==============================] - 16s 325us/step - loss: 0.5964 - accuracy: 0.7873 - val_loss: 1.8918 - val_accuracy: 0.5186
# Epoch 55/100
# 50000/50000 [==============================] - 17s 333us/step - loss: 0.5855 - accuracy: 0.7895 - val_loss: 1.9555 - val_accuracy: 0.5191
# Epoch 56/100
# 50000/50000 [==============================] - 17s 341us/step - loss: 0.5750 - accuracy: 0.7935 - val_loss: 1.9459 - val_accuracy: 0.5145
# Epoch 57/100
# 50000/50000 [==============================] - 17s 341us/step - loss: 0.5537 - accuracy: 0.8019 - val_loss: 1.9554 - val_accuracy: 0.5084
# Epoch 58/100
# 50000/50000 [==============================] - 17s 335us/step - loss: 0.5589 - accuracy: 0.7986 - val_loss: 2.0258 - val_accuracy: 0.5149
# Epoch 59/100
# 50000/50000 [==============================] - 17s 337us/step - loss: 0.5544 - accuracy: 0.8015 - val_loss: 2.0320 - val_accuracy: 0.5104
# Epoch 60/100
# 50000/50000 [==============================] - 17s 337us/step - loss: 0.5326 - accuracy: 0.8108 - val_loss: 2.1218 - val_accuracy: 0.5045
# Epoch 61/100
# 50000/50000 [==============================] - 17s 337us/step - loss: 0.5170 - accuracy: 0.8144 - val_loss: 2.1183 - val_accuracy: 0.5173
# Epoch 62/100
# 50000/50000 [==============================] - 17s 337us/step - loss: 0.5074 - accuracy: 0.8190 - val_loss: 2.1522 - val_accuracy: 0.5127
# Epoch 63/100
# 50000/50000 [==============================] - 17s 339us/step - loss: 0.5021 - accuracy: 0.8195 - val_loss: 2.1814 - val_accuracy: 0.5153
# Epoch 64/100
# 50000/50000 [==============================] - 17s 347us/step - loss: 0.4880 - accuracy: 0.8261 - val_loss: 2.1342 - val_accuracy: 0.5114
# Epoch 65/100
# 50000/50000 [==============================] - 17s 338us/step - loss: 0.4784 - accuracy: 0.8298 - val_loss: 2.1916 - val_accuracy: 0.5119
# Epoch 66/100
# 50000/50000 [==============================] - 17s 346us/step - loss: 0.4776 - accuracy: 0.8275 - val_loss: 2.2968 - val_accuracy: 0.5043
# Epoch 67/100
# 50000/50000 [==============================] - 17s 339us/step - loss: 0.4601 - accuracy: 0.8357 - val_loss: 2.2841 - val_accuracy: 0.5113
# Epoch 68/100
# 50000/50000 [==============================] - 17s 337us/step - loss: 0.4704 - accuracy: 0.8299 - val_loss: 2.2805 - val_accuracy: 0.5010
# Epoch 69/100
# 50000/50000 [==============================] - 17s 339us/step - loss: 0.4497 - accuracy: 0.8388 - val_loss: 2.3396 - val_accuracy: 0.5041
# Epoch 70/100
# 50000/50000 [==============================] - 17s 339us/step - loss: 0.4483 - accuracy: 0.8387 - val_loss: 2.4024 - val_accuracy: 0.5009
# Epoch 71/100
# 50000/50000 [==============================] - 17s 340us/step - loss: 0.4337 - accuracy: 0.8447 - val_loss: 2.4139 - val_accuracy: 0.4986
# Epoch 72/100
# 50000/50000 [==============================] - 17s 341us/step - loss: 0.4435 - accuracy: 0.8401 - val_loss: 2.4014 - val_accuracy: 0.5043
# Epoch 73/100
# 50000/50000 [==============================] - 17s 341us/step - loss: 0.4208 - accuracy: 0.8487 - val_loss: 2.4269 - val_accuracy: 0.5005
# Epoch 74/100
# 50000/50000 [==============================] - 17s 341us/step - loss: 0.4136 - accuracy: 0.8523 - val_loss: 2.4765 - val_accuracy: 0.5083
# Epoch 75/100
# 50000/50000 [==============================] - 17s 339us/step - loss: 0.4048 - accuracy: 0.8559 - val_loss: 2.4925 - val_accuracy: 0.5028
# Epoch 76/100
# 50000/50000 [==============================] - 17s 342us/step - loss: 0.3994 - accuracy: 0.8560 - val_loss: 2.6267 - val_accuracy: 0.4948
# Epoch 77/100
# 50000/50000 [==============================] - 17s 339us/step - loss: 0.4077 - accuracy: 0.8526 - val_loss: 2.5681 - val_accuracy: 0.5114
# Epoch 78/100
# 50000/50000 [==============================] - 17s 340us/step - loss: 0.3907 - accuracy: 0.8605 - val_loss: 2.6669 - val_accuracy: 0.4989
# Epoch 79/100
# 50000/50000 [==============================] - 17s 349us/step - loss: 0.3777 - accuracy: 0.8636 - val_loss: 2.7219 - val_accuracy: 0.5016
# Epoch 80/100
# 50000/50000 [==============================] - 16s 312us/step - loss: 0.3653 - accuracy: 0.8682 - val_loss: 2.8056 - val_accuracy: 0.4947
# Epoch 81/100
# 50000/50000 [==============================] - 16s 313us/step - loss: 0.3888 - accuracy: 0.8588 - val_loss: 2.6936 - val_accuracy: 0.5088
# Epoch 82/100
# 50000/50000 [==============================] - 16s 321us/step - loss: 0.3864 - accuracy: 0.8617 - val_loss: 2.7555 - val_accuracy: 0.5027
# Epoch 83/100
# 50000/50000 [==============================] - 16s 316us/step - loss: 0.3728 - accuracy: 0.8645 - val_loss: 2.8751 - val_accuracy: 0.4948
# Epoch 84/100
# 50000/50000 [==============================] - 17s 335us/step - loss: 0.3575 - accuracy: 0.8719 - val_loss: 2.8581 - val_accuracy: 0.5061
# Epoch 85/100
# 50000/50000 [==============================] - 17s 347us/step - loss: 0.3627 - accuracy: 0.8685 - val_loss: 2.8925 - val_accuracy: 0.5001
# Epoch 86/100
# 50000/50000 [==============================] - 17s 349us/step - loss: 0.3447 - accuracy: 0.8759 - val_loss: 2.9867 - val_accuracy: 0.4953
# Epoch 87/100
# 50000/50000 [==============================] - 17s 340us/step - loss: 0.3301 - accuracy: 0.8808 - val_loss: 2.9184 - val_accuracy: 0.5032
# Epoch 88/100
# 50000/50000 [==============================] - 17s 334us/step - loss: 0.3078 - accuracy: 0.8906 - val_loss: 2.9279 - val_accuracy: 0.5033
# Epoch 89/100
# 50000/50000 [==============================] - 17s 337us/step - loss: 0.3235 - accuracy: 0.8821 - val_loss: 3.0802 - val_accuracy: 0.4960
# Epoch 90/100
# 36096/50000 [====================>.........] - ETA: 4s - loss: 0.3301 - accuracy: 0.8824

# %%
import matplotlib.pyplot as plt
# 以視覺畫方式檢視訓練過程

train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]

train_acc = model.history.history["acc"]
valid_acc = model.history.history["val_acc"]

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()
