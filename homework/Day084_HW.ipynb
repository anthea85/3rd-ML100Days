# %% [markdown]
# ## Work
# ### 請結合前面的知識與程式碼，比較不同的 regularization 的組合對訓練的結果與影響：如 dropout, regularizers, batch-normalization 等

# %%
import os
import keras
import itertools
# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization
from keras.layers import Dropout
from keras.regularizers import l1, l2, l1_l2
"""
建立神經網路，並加入 BN layer
"""
def build_Batch(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)

        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

def build_Dropout(input_shape, output_units=10, num_neurons=[512, 256, 128], drp_ratio=0.2):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = Dropout(drp_ratio)(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = Dropout(drp_ratio)(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

def build_regularizers(input_shape, output_units=10, num_neurons=[512, 256, 128], l2_ratio=1e-4):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1), 
                                   kernel_regularizer=l2(l2_ratio))(input_layer)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1),
                                   kernel_regularizer=l2(l2_ratio))(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
"""Code Here
設定超參數
"""
LEARNING_RATE = 1e-3
EPOCHS = 50
BATCH_SIZE = 256
MOMENTUM = 0.95
L2_EXP = [1e-2, 1e-4, 1e-8, 1e-12]
Dropout_EXP = 0.25

# %%
results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""
model = build_Batch(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True)

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 35s 694us/step - loss: 1.8736 - accuracy: 0.3592 - val_loss: 1.7964 - val_accuracy: 0.3700
# Epoch 2/50
# 50000/50000 [==============================] - 14s 287us/step - loss: 1.5504 - accuracy: 0.4582 - val_loss: 1.5824 - val_accuracy: 0.4443
# Epoch 3/50
# 50000/50000 [==============================] - 14s 289us/step - loss: 1.4422 - accuracy: 0.4935 - val_loss: 1.5294 - val_accuracy: 0.4632
# Epoch 4/50
# 50000/50000 [==============================] - 15s 303us/step - loss: 1.3681 - accuracy: 0.5202 - val_loss: 1.5610 - val_accuracy: 0.4433
# Epoch 5/50
# 50000/50000 [==============================] - 15s 298us/step - loss: 1.3124 - accuracy: 0.5394 - val_loss: 1.5236 - val_accuracy: 0.4636
# Epoch 6/50
# 50000/50000 [==============================] - 15s 298us/step - loss: 1.2590 - accuracy: 0.5589 - val_loss: 1.4904 - val_accuracy: 0.4731
# Epoch 7/50
# 50000/50000 [==============================] - 15s 297us/step - loss: 1.2163 - accuracy: 0.5726 - val_loss: 1.5435 - val_accuracy: 0.4532
# Epoch 8/50
# 50000/50000 [==============================] - 15s 299us/step - loss: 1.1666 - accuracy: 0.5927 - val_loss: 1.4670 - val_accuracy: 0.4827
# Epoch 9/50
# 50000/50000 [==============================] - 15s 300us/step - loss: 1.1317 - accuracy: 0.6040 - val_loss: 1.4959 - val_accuracy: 0.4743
# Epoch 10/50
# 50000/50000 [==============================] - 15s 303us/step - loss: 1.0924 - accuracy: 0.6211 - val_loss: 1.4593 - val_accuracy: 0.4866
# Epoch 11/50
# 50000/50000 [==============================] - 15s 303us/step - loss: 1.0521 - accuracy: 0.6322 - val_loss: 1.4545 - val_accuracy: 0.4964
# Epoch 12/50
# 50000/50000 [==============================] - 15s 299us/step - loss: 1.0176 - accuracy: 0.6463 - val_loss: 1.5257 - val_accuracy: 0.4726
# Epoch 13/50
# 50000/50000 [==============================] - 15s 297us/step - loss: 0.9786 - accuracy: 0.6623 - val_loss: 1.5691 - val_accuracy: 0.4668
# Epoch 14/50
# 50000/50000 [==============================] - 15s 297us/step - loss: 0.9451 - accuracy: 0.6738 - val_loss: 1.4835 - val_accuracy: 0.4943
# Epoch 15/50
# 50000/50000 [==============================] - 15s 299us/step - loss: 0.9120 - accuracy: 0.6872 - val_loss: 1.6299 - val_accuracy: 0.4506
# Epoch 16/50
# 50000/50000 [==============================] - 15s 305us/step - loss: 0.8786 - accuracy: 0.6962 - val_loss: 1.5517 - val_accuracy: 0.4874
# Epoch 17/50
# 50000/50000 [==============================] - 15s 301us/step - loss: 0.8499 - accuracy: 0.7086 - val_loss: 1.6264 - val_accuracy: 0.4775
# Epoch 18/50
# 50000/50000 [==============================] - 15s 299us/step - loss: 0.8143 - accuracy: 0.7213 - val_loss: 1.5839 - val_accuracy: 0.4807
# Epoch 19/50
# 50000/50000 [==============================] - 15s 298us/step - loss: 0.7824 - accuracy: 0.7339 - val_loss: 1.6974 - val_accuracy: 0.4712
# Epoch 20/50
# 50000/50000 [==============================] - 15s 300us/step - loss: 0.7632 - accuracy: 0.7401 - val_loss: 1.5747 - val_accuracy: 0.4861
# Epoch 21/50
# 50000/50000 [==============================] - 15s 300us/step - loss: 0.7293 - accuracy: 0.7530 - val_loss: 1.6375 - val_accuracy: 0.4896
# Epoch 22/50
# 50000/50000 [==============================] - 15s 299us/step - loss: 0.7015 - accuracy: 0.7642 - val_loss: 1.6510 - val_accuracy: 0.4753
# Epoch 23/50
# 50000/50000 [==============================] - 15s 300us/step - loss: 0.6738 - accuracy: 0.7730 - val_loss: 1.7027 - val_accuracy: 0.4779
# Epoch 24/50
# 50000/50000 [==============================] - 15s 301us/step - loss: 0.6424 - accuracy: 0.7842 - val_loss: 1.8728 - val_accuracy: 0.4453
# Epoch 25/50
# 50000/50000 [==============================] - 15s 299us/step - loss: 0.6143 - accuracy: 0.7940 - val_loss: 1.6910 - val_accuracy: 0.4797
# Epoch 26/50
# 50000/50000 [==============================] - 15s 299us/step - loss: 0.5863 - accuracy: 0.8080 - val_loss: 1.7082 - val_accuracy: 0.4785
# Epoch 27/50
# 50000/50000 [==============================] - 15s 299us/step - loss: 0.5636 - accuracy: 0.8126 - val_loss: 1.7045 - val_accuracy: 0.4810
# Epoch 28/50
# 50000/50000 [==============================] - 15s 301us/step - loss: 0.5386 - accuracy: 0.8226 - val_loss: 1.7903 - val_accuracy: 0.4856
# Epoch 29/50
# 50000/50000 [==============================] - 15s 298us/step - loss: 0.5148 - accuracy: 0.8314 - val_loss: 1.8655 - val_accuracy: 0.4610
# Epoch 30/50
# 50000/50000 [==============================] - 15s 300us/step - loss: 0.4908 - accuracy: 0.8390 - val_loss: 1.8416 - val_accuracy: 0.4676
# Epoch 31/50
# 50000/50000 [==============================] - 15s 297us/step - loss: 0.4695 - accuracy: 0.8494 - val_loss: 1.8432 - val_accuracy: 0.4831
# Epoch 32/50
# 50000/50000 [==============================] - 15s 300us/step - loss: 0.4539 - accuracy: 0.8533 - val_loss: 1.9030 - val_accuracy: 0.4713
# Epoch 33/50
# 50000/50000 [==============================] - 15s 301us/step - loss: 0.4332 - accuracy: 0.8614 - val_loss: 1.9424 - val_accuracy: 0.4733
# Epoch 34/50
# 50000/50000 [==============================] - 16s 312us/step - loss: 0.4067 - accuracy: 0.8709 - val_loss: 1.9558 - val_accuracy: 0.4784
# Epoch 35/50
# 50000/50000 [==============================] - 16s 329us/step - loss: 0.3883 - accuracy: 0.8778 - val_loss: 2.0277 - val_accuracy: 0.4643
# Epoch 36/50
# 50000/50000 [==============================] - 16s 318us/step - loss: 0.3666 - accuracy: 0.8854 - val_loss: 2.0062 - val_accuracy: 0.4810
# Epoch 37/50
# 50000/50000 [==============================] - 15s 304us/step - loss: 0.3506 - accuracy: 0.8906 - val_loss: 2.0704 - val_accuracy: 0.4557
# Epoch 38/50
# 50000/50000 [==============================] - 15s 298us/step - loss: 0.3340 - accuracy: 0.8970 - val_loss: 2.1252 - val_accuracy: 0.4629
# Epoch 39/50
# 50000/50000 [==============================] - 15s 299us/step - loss: 0.3126 - accuracy: 0.9044 - val_loss: 2.1495 - val_accuracy: 0.4574
# Epoch 40/50
# 50000/50000 [==============================] - 15s 302us/step - loss: 0.2980 - accuracy: 0.9099 - val_loss: 2.1476 - val_accuracy: 0.4775
# Epoch 41/50
# 50000/50000 [==============================] - 15s 300us/step - loss: 0.2871 - accuracy: 0.9133 - val_loss: 2.0601 - val_accuracy: 0.4769
# Epoch 42/50
# 50000/50000 [==============================] - 15s 299us/step - loss: 0.2666 - accuracy: 0.9228 - val_loss: 2.2032 - val_accuracy: 0.4714
# Epoch 43/50
# 50000/50000 [==============================] - 15s 300us/step - loss: 0.2631 - accuracy: 0.9221 - val_loss: 2.2148 - val_accuracy: 0.4690
# Epoch 44/50
# 50000/50000 [==============================] - 15s 299us/step - loss: 0.2513 - accuracy: 0.9252 - val_loss: 2.2036 - val_accuracy: 0.4633
# Epoch 45/50
# 50000/50000 [==============================] - 15s 300us/step - loss: 0.2348 - accuracy: 0.9317 - val_loss: 2.3632 - val_accuracy: 0.4656
# Epoch 46/50
# 50000/50000 [==============================] - 15s 293us/step - loss: 0.2264 - accuracy: 0.9348 - val_loss: 2.2217 - val_accuracy: 0.4735
# Epoch 47/50
# 50000/50000 [==============================] - 15s 293us/step - loss: 0.2133 - accuracy: 0.9392 - val_loss: 2.5535 - val_accuracy: 0.4552
# Epoch 48/50
# 50000/50000 [==============================] - 15s 293us/step - loss: 0.2031 - accuracy: 0.9423 - val_loss: 2.4883 - val_accuracy: 0.4517
# Epoch 49/50
# 50000/50000 [==============================] - 15s 291us/step - loss: 0.1975 - accuracy: 0.9445 - val_loss: 2.3792 - val_accuracy: 0.4772
# Epoch 50/50
# 50000/50000 [==============================] - 15s 293us/step - loss: 0.1842 - accuracy: 0.9493 - val_loss: 2.4189 - val_accuracy: 0.4682

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""
plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

# %%
results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""
model = build_Dropout(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True)

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 15s 301us/step - loss: 2.1562 - accuracy: 0.1983 - val_loss: 1.9644 - val_accuracy: 0.3059
# Epoch 2/50
# 50000/50000 [==============================] - 15s 291us/step - loss: 1.9646 - accuracy: 0.2873 - val_loss: 1.8467 - val_accuracy: 0.3472
# Epoch 3/50
# 50000/50000 [==============================] - 15s 293us/step - loss: 1.8803 - accuracy: 0.3248 - val_loss: 1.7791 - val_accuracy: 0.3687
# Epoch 4/50
# 50000/50000 [==============================] - 15s 292us/step - loss: 1.8232 - accuracy: 0.3471 - val_loss: 1.7205 - val_accuracy: 0.3890
# Epoch 5/50
# 50000/50000 [==============================] - 15s 293us/step - loss: 1.7748 - accuracy: 0.3669 - val_loss: 1.6858 - val_accuracy: 0.4071
# Epoch 6/50
# 50000/50000 [==============================] - 15s 293us/step - loss: 1.7404 - accuracy: 0.3791 - val_loss: 1.6478 - val_accuracy: 0.4159
# Epoch 7/50
# 50000/50000 [==============================] - 14s 290us/step - loss: 1.7095 - accuracy: 0.3897 - val_loss: 1.6199 - val_accuracy: 0.4233
# Epoch 8/50
# 50000/50000 [==============================] - 15s 291us/step - loss: 1.6815 - accuracy: 0.4003 - val_loss: 1.5983 - val_accuracy: 0.4324
# Epoch 9/50
# 50000/50000 [==============================] - 15s 291us/step - loss: 1.6615 - accuracy: 0.4085 - val_loss: 1.5739 - val_accuracy: 0.4417
# Epoch 10/50
# 50000/50000 [==============================] - 15s 290us/step - loss: 1.6363 - accuracy: 0.4168 - val_loss: 1.5550 - val_accuracy: 0.4452
# Epoch 11/50
# 50000/50000 [==============================] - 15s 291us/step - loss: 1.6231 - accuracy: 0.4225 - val_loss: 1.5432 - val_accuracy: 0.4539
# Epoch 12/50
# 50000/50000 [==============================] - 15s 291us/step - loss: 1.6018 - accuracy: 0.4309 - val_loss: 1.5219 - val_accuracy: 0.4592
# Epoch 13/50
# 50000/50000 [==============================] - 15s 292us/step - loss: 1.5865 - accuracy: 0.4368 - val_loss: 1.5159 - val_accuracy: 0.4613
# Epoch 14/50
# 50000/50000 [==============================] - 15s 290us/step - loss: 1.5679 - accuracy: 0.4460 - val_loss: 1.4914 - val_accuracy: 0.4681
# Epoch 15/50
# 50000/50000 [==============================] - 15s 293us/step - loss: 1.5509 - accuracy: 0.4465 - val_loss: 1.4850 - val_accuracy: 0.4726
# Epoch 16/50
# 50000/50000 [==============================] - 15s 291us/step - loss: 1.5385 - accuracy: 0.4542 - val_loss: 1.4716 - val_accuracy: 0.4771
# Epoch 17/50
# 50000/50000 [==============================] - 15s 291us/step - loss: 1.5267 - accuracy: 0.4584 - val_loss: 1.4673 - val_accuracy: 0.4781
# Epoch 18/50
# 50000/50000 [==============================] - 14s 290us/step - loss: 1.5109 - accuracy: 0.4633 - val_loss: 1.4501 - val_accuracy: 0.4869
# Epoch 19/50
# 50000/50000 [==============================] - 15s 293us/step - loss: 1.4955 - accuracy: 0.4690 - val_loss: 1.4342 - val_accuracy: 0.4902
# Epoch 20/50
# 50000/50000 [==============================] - 15s 293us/step - loss: 1.4853 - accuracy: 0.4744 - val_loss: 1.4359 - val_accuracy: 0.4931
# Epoch 21/50
# 50000/50000 [==============================] - 15s 294us/step - loss: 1.4749 - accuracy: 0.4749 - val_loss: 1.4287 - val_accuracy: 0.4945
# Epoch 22/50
# 50000/50000 [==============================] - 15s 293us/step - loss: 1.4640 - accuracy: 0.4778 - val_loss: 1.4124 - val_accuracy: 0.4954
# Epoch 23/50
# 50000/50000 [==============================] - 15s 294us/step - loss: 1.4511 - accuracy: 0.4834 - val_loss: 1.4004 - val_accuracy: 0.4985
# Epoch 24/50
# 50000/50000 [==============================] - 15s 295us/step - loss: 1.4396 - accuracy: 0.4904 - val_loss: 1.3963 - val_accuracy: 0.5023
# Epoch 25/50
# 50000/50000 [==============================] - 15s 301us/step - loss: 1.4288 - accuracy: 0.4931 - val_loss: 1.3912 - val_accuracy: 0.5002
# Epoch 26/50
# 50000/50000 [==============================] - 15s 297us/step - loss: 1.4186 - accuracy: 0.4955 - val_loss: 1.3873 - val_accuracy: 0.5029
# Epoch 27/50
# 50000/50000 [==============================] - 15s 296us/step - loss: 1.4102 - accuracy: 0.4978 - val_loss: 1.3740 - val_accuracy: 0.5101
# Epoch 28/50
# 50000/50000 [==============================] - 15s 295us/step - loss: 1.4013 - accuracy: 0.5012 - val_loss: 1.3715 - val_accuracy: 0.5110
# Epoch 29/50
# 50000/50000 [==============================] - 15s 293us/step - loss: 1.3907 - accuracy: 0.5051 - val_loss: 1.3579 - val_accuracy: 0.5179
# Epoch 30/50
# 50000/50000 [==============================] - 15s 294us/step - loss: 1.3823 - accuracy: 0.5077 - val_loss: 1.3620 - val_accuracy: 0.5106
# Epoch 31/50
# 50000/50000 [==============================] - 15s 294us/step - loss: 1.3695 - accuracy: 0.5130 - val_loss: 1.3507 - val_accuracy: 0.5177
# Epoch 32/50
# 50000/50000 [==============================] - 15s 294us/step - loss: 1.3627 - accuracy: 0.5145 - val_loss: 1.3442 - val_accuracy: 0.5229
# Epoch 33/50
# 50000/50000 [==============================] - 15s 295us/step - loss: 1.3475 - accuracy: 0.5204 - val_loss: 1.3458 - val_accuracy: 0.5211
# Epoch 34/50
# 50000/50000 [==============================] - 15s 295us/step - loss: 1.3459 - accuracy: 0.5200 - val_loss: 1.3437 - val_accuracy: 0.5178
# Epoch 35/50
# 50000/50000 [==============================] - 15s 296us/step - loss: 1.3353 - accuracy: 0.5252 - val_loss: 1.3399 - val_accuracy: 0.5235
# Epoch 36/50
# 50000/50000 [==============================] - 15s 295us/step - loss: 1.3268 - accuracy: 0.5261 - val_loss: 1.3291 - val_accuracy: 0.5253
# Epoch 37/50
# 50000/50000 [==============================] - 15s 296us/step - loss: 1.3178 - accuracy: 0.5290 - val_loss: 1.3397 - val_accuracy: 0.5220
# Epoch 38/50
# 50000/50000 [==============================] - 15s 297us/step - loss: 1.3082 - accuracy: 0.5332 - val_loss: 1.3393 - val_accuracy: 0.5181
# Epoch 39/50
# 50000/50000 [==============================] - 15s 307us/step - loss: 1.3037 - accuracy: 0.5347 - val_loss: 1.3198 - val_accuracy: 0.5281
# Epoch 40/50
# 50000/50000 [==============================] - 17s 341us/step - loss: 1.3001 - accuracy: 0.5370 - val_loss: 1.3143 - val_accuracy: 0.5294
# Epoch 41/50
# 50000/50000 [==============================] - 15s 297us/step - loss: 1.2859 - accuracy: 0.5413 - val_loss: 1.3155 - val_accuracy: 0.5281
# Epoch 42/50
# 50000/50000 [==============================] - 15s 298us/step - loss: 1.2786 - accuracy: 0.5446 - val_loss: 1.3102 - val_accuracy: 0.5359
# Epoch 43/50
# 50000/50000 [==============================] - 15s 298us/step - loss: 1.2698 - accuracy: 0.5489 - val_loss: 1.3233 - val_accuracy: 0.5293
# Epoch 44/50
# 50000/50000 [==============================] - 15s 297us/step - loss: 1.2636 - accuracy: 0.5501 - val_loss: 1.3059 - val_accuracy: 0.5354
# Epoch 45/50
# 50000/50000 [==============================] - 15s 297us/step - loss: 1.2611 - accuracy: 0.5521 - val_loss: 1.3101 - val_accuracy: 0.5363
# Epoch 46/50
# 50000/50000 [==============================] - 15s 293us/step - loss: 1.2529 - accuracy: 0.5519 - val_loss: 1.2968 - val_accuracy: 0.5372
# Epoch 47/50
# 50000/50000 [==============================] - 15s 292us/step - loss: 1.2443 - accuracy: 0.5570 - val_loss: 1.2937 - val_accuracy: 0.5379
# Epoch 48/50
# 50000/50000 [==============================] - 14s 289us/step - loss: 1.2383 - accuracy: 0.5572 - val_loss: 1.3002 - val_accuracy: 0.5358
# Epoch 49/50
# 50000/50000 [==============================] - 14s 290us/step - loss: 1.2308 - accuracy: 0.5578 - val_loss: 1.2871 - val_accuracy: 0.5446
# Epoch 50/50
# 50000/50000 [==============================] - 15s 291us/step - loss: 1.2266 - accuracy: 0.5624 - val_loss: 1.2907 - val_accuracy: 0.5411

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""
plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

# %%
results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""
model = build_regularizers(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True)

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 16s 329us/step - loss: 2.1714 - accuracy: 0.2767 - val_loss: 2.0069 - val_accuracy: 0.3452
# Epoch 2/50
# 50000/50000 [==============================] - 16s 318us/step - loss: 1.9426 - accuracy: 0.3668 - val_loss: 1.8973 - val_accuracy: 0.3837
# Epoch 3/50
# 50000/50000 [==============================] - 16s 319us/step - loss: 1.8571 - accuracy: 0.3985 - val_loss: 1.8264 - val_accuracy: 0.4130
# Epoch 4/50
# 50000/50000 [==============================] - 16s 323us/step - loss: 1.7968 - accuracy: 0.4191 - val_loss: 1.7788 - val_accuracy: 0.4235
# Epoch 5/50
# 50000/50000 [==============================] - 16s 318us/step - loss: 1.7483 - accuracy: 0.4353 - val_loss: 1.7420 - val_accuracy: 0.4329
# Epoch 6/50
# 50000/50000 [==============================] - 16s 319us/step - loss: 1.7090 - accuracy: 0.4501 - val_loss: 1.7033 - val_accuracy: 0.4493
# Epoch 7/50
# 50000/50000 [==============================] - 16s 319us/step - loss: 1.6754 - accuracy: 0.4613 - val_loss: 1.6767 - val_accuracy: 0.4586
# Epoch 8/50
# 50000/50000 [==============================] - 16s 320us/step - loss: 1.6446 - accuracy: 0.4721 - val_loss: 1.6543 - val_accuracy: 0.4662
# Epoch 9/50
# 50000/50000 [==============================] - 16s 322us/step - loss: 1.6175 - accuracy: 0.4803 - val_loss: 1.6296 - val_accuracy: 0.4751
# Epoch 10/50
# 50000/50000 [==============================] - 16s 320us/step - loss: 1.5916 - accuracy: 0.4906 - val_loss: 1.6277 - val_accuracy: 0.4762
# Epoch 11/50
# 50000/50000 [==============================] - 16s 319us/step - loss: 1.5689 - accuracy: 0.4987 - val_loss: 1.5928 - val_accuracy: 0.4883
# Epoch 12/50
# 50000/50000 [==============================] - 16s 321us/step - loss: 1.5486 - accuracy: 0.5051 - val_loss: 1.5959 - val_accuracy: 0.4862
# Epoch 13/50
# 50000/50000 [==============================] - 16s 321us/step - loss: 1.5248 - accuracy: 0.5137 - val_loss: 1.5881 - val_accuracy: 0.4925
# Epoch 14/50
# 50000/50000 [==============================] - 16s 327us/step - loss: 1.5034 - accuracy: 0.5187 - val_loss: 1.5763 - val_accuracy: 0.4909
# Epoch 15/50
# 50000/50000 [==============================] - 17s 333us/step - loss: 1.4860 - accuracy: 0.5262 - val_loss: 1.5510 - val_accuracy: 0.5035
# Epoch 16/50
# 50000/50000 [==============================] - 16s 320us/step - loss: 1.4682 - accuracy: 0.5330 - val_loss: 1.5438 - val_accuracy: 0.5003
# Epoch 17/50
# 50000/50000 [==============================] - 16s 320us/step - loss: 1.4502 - accuracy: 0.5390 - val_loss: 1.5326 - val_accuracy: 0.5077
# Epoch 18/50
# 50000/50000 [==============================] - 16s 320us/step - loss: 1.4336 - accuracy: 0.5425 - val_loss: 1.5364 - val_accuracy: 0.5056
# Epoch 19/50
# 50000/50000 [==============================] - 16s 320us/step - loss: 1.4160 - accuracy: 0.5515 - val_loss: 1.5273 - val_accuracy: 0.5090
# Epoch 20/50
# 50000/50000 [==============================] - 16s 320us/step - loss: 1.4004 - accuracy: 0.5563 - val_loss: 1.5205 - val_accuracy: 0.5109
# Epoch 21/50
# 50000/50000 [==============================] - 16s 320us/step - loss: 1.3860 - accuracy: 0.5599 - val_loss: 1.5169 - val_accuracy: 0.5139
# Epoch 22/50
# 50000/50000 [==============================] - 16s 320us/step - loss: 1.3709 - accuracy: 0.5658 - val_loss: 1.5116 - val_accuracy: 0.5188
# Epoch 23/50
# 50000/50000 [==============================] - 16s 320us/step - loss: 1.3563 - accuracy: 0.5694 - val_loss: 1.5903 - val_accuracy: 0.4996
# Epoch 24/50
# 50000/50000 [==============================] - 16s 320us/step - loss: 1.3415 - accuracy: 0.5777 - val_loss: 1.5135 - val_accuracy: 0.5127
# Epoch 25/50
# 50000/50000 [==============================] - 16s 321us/step - loss: 1.3281 - accuracy: 0.5808 - val_loss: 1.5357 - val_accuracy: 0.5020
# Epoch 26/50
# 50000/50000 [==============================] - 16s 321us/step - loss: 1.3138 - accuracy: 0.5856 - val_loss: 1.4873 - val_accuracy: 0.5234
# Epoch 27/50
# 50000/50000 [==============================] - 16s 320us/step - loss: 1.2982 - accuracy: 0.5919 - val_loss: 1.5406 - val_accuracy: 0.5120
# Epoch 28/50
# 50000/50000 [==============================] - 16s 321us/step - loss: 1.2858 - accuracy: 0.5970 - val_loss: 1.5281 - val_accuracy: 0.5121
# Epoch 29/50
# 50000/50000 [==============================] - 16s 322us/step - loss: 1.2713 - accuracy: 0.6016 - val_loss: 1.5988 - val_accuracy: 0.4928
# Epoch 30/50
# 50000/50000 [==============================] - 16s 321us/step - loss: 1.2593 - accuracy: 0.6054 - val_loss: 1.5410 - val_accuracy: 0.5081
# Epoch 31/50
# 50000/50000 [==============================] - 16s 321us/step - loss: 1.2443 - accuracy: 0.6086 - val_loss: 1.4960 - val_accuracy: 0.5230
# Epoch 32/50
# 50000/50000 [==============================] - 16s 321us/step - loss: 1.2325 - accuracy: 0.6160 - val_loss: 1.4647 - val_accuracy: 0.5352
# Epoch 33/50
# 50000/50000 [==============================] - 16s 321us/step - loss: 1.2193 - accuracy: 0.6199 - val_loss: 1.4912 - val_accuracy: 0.5185
# Epoch 34/50
# 50000/50000 [==============================] - 16s 329us/step - loss: 1.2083 - accuracy: 0.6233 - val_loss: 1.4801 - val_accuracy: 0.5326
# Epoch 35/50
# 50000/50000 [==============================] - 16s 323us/step - loss: 1.1926 - accuracy: 0.6274 - val_loss: 1.5364 - val_accuracy: 0.5163
# Epoch 36/50
# 50000/50000 [==============================] - 16s 321us/step - loss: 1.1799 - accuracy: 0.6304 - val_loss: 1.4857 - val_accuracy: 0.5298
# Epoch 37/50
# 50000/50000 [==============================] - 16s 322us/step - loss: 1.1703 - accuracy: 0.6369 - val_loss: 1.4734 - val_accuracy: 0.5355
# Epoch 38/50
# 50000/50000 [==============================] - 16s 322us/step - loss: 1.1607 - accuracy: 0.6387 - val_loss: 1.5254 - val_accuracy: 0.5201
# Epoch 39/50
# 50000/50000 [==============================] - 16s 321us/step - loss: 1.1480 - accuracy: 0.6435 - val_loss: 1.5715 - val_accuracy: 0.5092
# Epoch 40/50
# 50000/50000 [==============================] - 16s 322us/step - loss: 1.1368 - accuracy: 0.6491 - val_loss: 1.5091 - val_accuracy: 0.5261
# Epoch 41/50
# 50000/50000 [==============================] - 16s 322us/step - loss: 1.1213 - accuracy: 0.6527 - val_loss: 1.4797 - val_accuracy: 0.5339
# Epoch 42/50
# 50000/50000 [==============================] - 16s 326us/step - loss: 1.1088 - accuracy: 0.6622 - val_loss: 1.4792 - val_accuracy: 0.5426
# Epoch 43/50
# 50000/50000 [==============================] - 16s 320us/step - loss: 1.0971 - accuracy: 0.6632 - val_loss: 1.4957 - val_accuracy: 0.5361
# Epoch 44/50
# 50000/50000 [==============================] - 16s 315us/step - loss: 1.0878 - accuracy: 0.6657 - val_loss: 1.5139 - val_accuracy: 0.5295
# Epoch 45/50
# 50000/50000 [==============================] - 16s 316us/step - loss: 1.0717 - accuracy: 0.6722 - val_loss: 1.6198 - val_accuracy: 0.5045
# Epoch 46/50
# 50000/50000 [==============================] - 16s 319us/step - loss: 1.0622 - accuracy: 0.6747 - val_loss: 1.6094 - val_accuracy: 0.5079
# Epoch 47/50
# 50000/50000 [==============================] - 16s 320us/step - loss: 1.0531 - accuracy: 0.6797 - val_loss: 1.5749 - val_accuracy: 0.5209
# Epoch 48/50
# 50000/50000 [==============================] - 16s 314us/step - loss: 1.0376 - accuracy: 0.6837 - val_loss: 1.6156 - val_accuracy: 0.5148
# Epoch 49/50
# 50000/50000 [==============================] - 16s 311us/step - loss: 1.0315 - accuracy: 0.6875 - val_loss: 1.6589 - val_accuracy: 0.5033
# Epoch 50/50
# 50000/50000 [==============================] - 16s 319us/step - loss: 1.0173 - accuracy: 0.6921 - val_loss: 1.5173 - val_accuracy: 0.5378

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""
plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()
