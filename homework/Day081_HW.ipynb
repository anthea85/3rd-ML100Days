# %% [markdown]
# ## Work
# 1. 請比較使用 l1, l1_l2 及不同比例下的訓練結果

# %%
import os
import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.regularizers import l1, l2, l1_l2

def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128], l2_ratio=1e-4):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1), 
                                   kernel_regularizer=l2(l2_ratio))(input_layer)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1),
                                   kernel_regularizer=l2(l2_ratio))(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
"""Code Here
設定超參數
"""
LEARNING_RATE = 1e-3
EPOCHS = 50
BATCH_SIZE = 256
MOMENTUM = 0.95
L2_EXP = [1e-2, 1e-4, 1e-8, 1e-12]

# %%
results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""
for regulizer_ratio in L2_EXP:
    keras.backend.clear_session() # 把舊的 Graph 清掉
    print("Experiment with Regulizer = %.6f" % (regulizer_ratio))
    model = build_mlp(input_shape=x_train.shape[1:], l2_ratio=regulizer_ratio)
    model.summary()
    optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
    model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

    model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=BATCH_SIZE, 
              validation_data=(x_test, y_test), 
              shuffle=True)
    
    # Collect results
    train_loss = model.history.history["loss"]
    valid_loss = model.history.history["val_loss"]
    train_acc = model.history.history["accuracy"]
    valid_acc = model.history.history["val_accuracy"]
    
    exp_name_tag = "exp-l2-%s" % str(regulizer_ratio)
    results[exp_name_tag] = {'train-loss': train_loss,
                             'valid-loss': valid_loss,
                             'train-acc': train_acc,
                             'valid-acc': valid_acc}
# Out:
# Experiment with Regulizer = 0.010000
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 21s 425us/step - loss: 15.0478 - accuracy: 0.2768 - val_loss: 13.9250 - val_accuracy: 0.3338
# Epoch 2/50
# 50000/50000 [==============================] - 21s 421us/step - loss: 12.9951 - accuracy: 0.3552 - val_loss: 12.1035 - val_accuracy: 0.3727
# Epoch 3/50
# 50000/50000 [==============================] - 21s 420us/step - loss: 11.3304 - accuracy: 0.3807 - val_loss: 10.5814 - val_accuracy: 0.3941
# Epoch 4/50
# 50000/50000 [==============================] - 20s 409us/step - loss: 9.9211 - accuracy: 0.3933 - val_loss: 9.2862 - val_accuracy: 0.3973
# Epoch 5/50
# 50000/50000 [==============================] - 20s 407us/step - loss: 8.7238 - accuracy: 0.4023 - val_loss: 8.1833 - val_accuracy: 0.4049
# Epoch 6/50
# 50000/50000 [==============================] - 21s 418us/step - loss: 7.7032 - accuracy: 0.4095 - val_loss: 7.2430 - val_accuracy: 0.4145
# Epoch 7/50
# 50000/50000 [==============================] - 20s 407us/step - loss: 6.8322 - accuracy: 0.4169 - val_loss: 6.4372 - val_accuracy: 0.4225
# Epoch 8/50
# 50000/50000 [==============================] - 20s 399us/step - loss: 6.0879 - accuracy: 0.4254 - val_loss: 5.7517 - val_accuracy: 0.4278
# Epoch 9/50
# 50000/50000 [==============================] - 19s 386us/step - loss: 5.4525 - accuracy: 0.4290 - val_loss: 5.1661 - val_accuracy: 0.4323
# Epoch 10/50
# 50000/50000 [==============================] - 20s 399us/step - loss: 4.9091 - accuracy: 0.4358 - val_loss: 4.6693 - val_accuracy: 0.4285
# Epoch 11/50
# 50000/50000 [==============================] - 20s 407us/step - loss: 4.4451 - accuracy: 0.4391 - val_loss: 4.2364 - val_accuracy: 0.4419
# Epoch 12/50
# 50000/50000 [==============================] - 19s 389us/step - loss: 4.0468 - accuracy: 0.4438 - val_loss: 3.8755 - val_accuracy: 0.4361
# Epoch 13/50
# 50000/50000 [==============================] - 19s 387us/step - loss: 3.7070 - accuracy: 0.4484 - val_loss: 3.5575 - val_accuracy: 0.4460
# Epoch 14/50
# 50000/50000 [==============================] - 19s 381us/step - loss: 3.4158 - accuracy: 0.4526 - val_loss: 3.2975 - val_accuracy: 0.4410
# Epoch 15/50
# 50000/50000 [==============================] - 19s 387us/step - loss: 3.1652 - accuracy: 0.4554 - val_loss: 3.0764 - val_accuracy: 0.4418
# Epoch 16/50
# 50000/50000 [==============================] - 19s 384us/step - loss: 2.9524 - accuracy: 0.4595 - val_loss: 2.8632 - val_accuracy: 0.4549
# Epoch 17/50
# 50000/50000 [==============================] - 19s 389us/step - loss: 2.7691 - accuracy: 0.4619 - val_loss: 2.6995 - val_accuracy: 0.4578
# Epoch 18/50
# 50000/50000 [==============================] - 20s 392us/step - loss: 2.6116 - accuracy: 0.4655 - val_loss: 2.5510 - val_accuracy: 0.4624
# Epoch 19/50
# 50000/50000 [==============================] - 19s 381us/step - loss: 2.4761 - accuracy: 0.4674 - val_loss: 2.4347 - val_accuracy: 0.4549
# Epoch 20/50
# 50000/50000 [==============================] - 19s 383us/step - loss: 2.3623 - accuracy: 0.4710 - val_loss: 2.3395 - val_accuracy: 0.4624
# Epoch 21/50
# 50000/50000 [==============================] - 19s 382us/step - loss: 2.2619 - accuracy: 0.4746 - val_loss: 2.2443 - val_accuracy: 0.4619
# Epoch 22/50
# 50000/50000 [==============================] - 19s 384us/step - loss: 2.1771 - accuracy: 0.4742 - val_loss: 2.1592 - val_accuracy: 0.4638
# Epoch 23/50
# 50000/50000 [==============================] - 19s 373us/step - loss: 2.1018 - accuracy: 0.4794 - val_loss: 2.0862 - val_accuracy: 0.4754
# Epoch 24/50
# 50000/50000 [==============================] - 19s 374us/step - loss: 2.0409 - accuracy: 0.4803 - val_loss: 2.0583 - val_accuracy: 0.4624
# Epoch 25/50
# 50000/50000 [==============================] - 19s 379us/step - loss: 1.9847 - accuracy: 0.4830 - val_loss: 2.0054 - val_accuracy: 0.4645
# Epoch 26/50
# 50000/50000 [==============================] - 19s 373us/step - loss: 1.9374 - accuracy: 0.4838 - val_loss: 1.9992 - val_accuracy: 0.4467
# Epoch 27/50
# 50000/50000 [==============================] - 18s 369us/step - loss: 1.8970 - accuracy: 0.4860 - val_loss: 1.9043 - val_accuracy: 0.4763
# Epoch 28/50
# 50000/50000 [==============================] - 19s 376us/step - loss: 1.8610 - accuracy: 0.4874 - val_loss: 1.8750 - val_accuracy: 0.4790
# Epoch 29/50
# 50000/50000 [==============================] - 19s 373us/step - loss: 1.8282 - accuracy: 0.4914 - val_loss: 1.8488 - val_accuracy: 0.4813
# Epoch 30/50
# 50000/50000 [==============================] - 19s 374us/step - loss: 1.8022 - accuracy: 0.4936 - val_loss: 1.8688 - val_accuracy: 0.4628
# Epoch 31/50
# 50000/50000 [==============================] - 19s 377us/step - loss: 1.7781 - accuracy: 0.4954 - val_loss: 1.8633 - val_accuracy: 0.4602
# Epoch 32/50
# 50000/50000 [==============================] - 19s 372us/step - loss: 1.7595 - accuracy: 0.4967 - val_loss: 1.7838 - val_accuracy: 0.4844
# Epoch 33/50
# 50000/50000 [==============================] - 20s 395us/step - loss: 1.7404 - accuracy: 0.4990 - val_loss: 1.7965 - val_accuracy: 0.4706
# Epoch 34/50
# 50000/50000 [==============================] - 19s 372us/step - loss: 1.7227 - accuracy: 0.5011 - val_loss: 1.7617 - val_accuracy: 0.4797
# Epoch 35/50
# 50000/50000 [==============================] - 19s 371us/step - loss: 1.7082 - accuracy: 0.5035 - val_loss: 1.7440 - val_accuracy: 0.4893
# Epoch 36/50
# 50000/50000 [==============================] - 19s 383us/step - loss: 1.6979 - accuracy: 0.5050 - val_loss: 1.7361 - val_accuracy: 0.4860
# Epoch 37/50
# 50000/50000 [==============================] - 19s 377us/step - loss: 1.6857 - accuracy: 0.5057 - val_loss: 1.7228 - val_accuracy: 0.4912
# Epoch 38/50
# 50000/50000 [==============================] - 19s 381us/step - loss: 1.6769 - accuracy: 0.5092 - val_loss: 1.7720 - val_accuracy: 0.4655
# Epoch 39/50
# 50000/50000 [==============================] - 19s 374us/step - loss: 1.6668 - accuracy: 0.5092 - val_loss: 1.7072 - val_accuracy: 0.4951
# Epoch 40/50
# 50000/50000 [==============================] - 18s 368us/step - loss: 1.6591 - accuracy: 0.5114 - val_loss: 1.7197 - val_accuracy: 0.4842
# Epoch 41/50
# 50000/50000 [==============================] - 19s 377us/step - loss: 1.6542 - accuracy: 0.5113 - val_loss: 1.7040 - val_accuracy: 0.4902
# Epoch 42/50
# 50000/50000 [==============================] - 19s 377us/step - loss: 1.6480 - accuracy: 0.5141 - val_loss: 1.6965 - val_accuracy: 0.4941
# Epoch 43/50
# 50000/50000 [==============================] - 20s 408us/step - loss: 1.6412 - accuracy: 0.5152 - val_loss: 1.6987 - val_accuracy: 0.4860
# Epoch 44/50
# 50000/50000 [==============================] - 19s 386us/step - loss: 1.6332 - accuracy: 0.5180 - val_loss: 1.7088 - val_accuracy: 0.4912
# Epoch 45/50
# 50000/50000 [==============================] - 19s 377us/step - loss: 1.6317 - accuracy: 0.5178 - val_loss: 1.7020 - val_accuracy: 0.4930
# Epoch 46/50
# 50000/50000 [==============================] - 19s 379us/step - loss: 1.6271 - accuracy: 0.5185 - val_loss: 1.7125 - val_accuracy: 0.4888
# Epoch 47/50
# 50000/50000 [==============================] - 19s 386us/step - loss: 1.6219 - accuracy: 0.5212 - val_loss: 1.6850 - val_accuracy: 0.4891
# Epoch 48/50
# 50000/50000 [==============================] - 18s 357us/step - loss: 1.6195 - accuracy: 0.5230 - val_loss: 1.6801 - val_accuracy: 0.4935
# Epoch 49/50
# 50000/50000 [==============================] - 18s 365us/step - loss: 1.6148 - accuracy: 0.5231 - val_loss: 1.6996 - val_accuracy: 0.4844
# Epoch 50/50
# 50000/50000 [==============================] - 18s 366us/step - loss: 1.6118 - accuracy: 0.5250 - val_loss: 1.7674 - val_accuracy: 0.4603
# Experiment with Regulizer = 0.000100
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 18s 367us/step - loss: 2.1465 - accuracy: 0.2800 - val_loss: 1.9949 - val_accuracy: 0.3454
# Epoch 2/50
# 50000/50000 [==============================] - 18s 364us/step - loss: 1.9359 - accuracy: 0.3708 - val_loss: 1.8859 - val_accuracy: 0.3906
# Epoch 3/50
# 50000/50000 [==============================] - 18s 365us/step - loss: 1.8535 - accuracy: 0.3997 - val_loss: 1.8246 - val_accuracy: 0.4048
# Epoch 4/50
# 50000/50000 [==============================] - 19s 371us/step - loss: 1.7954 - accuracy: 0.4189 - val_loss: 1.7817 - val_accuracy: 0.4277
# Epoch 5/50
# 50000/50000 [==============================] - 18s 365us/step - loss: 1.7475 - accuracy: 0.4380 - val_loss: 1.7373 - val_accuracy: 0.4378
# Epoch 6/50
# 50000/50000 [==============================] - 18s 360us/step - loss: 1.7092 - accuracy: 0.4503 - val_loss: 1.7056 - val_accuracy: 0.4427
# Epoch 7/50
# 50000/50000 [==============================] - 18s 361us/step - loss: 1.6749 - accuracy: 0.4622 - val_loss: 1.6853 - val_accuracy: 0.4492
# Epoch 8/50
# 50000/50000 [==============================] - 18s 361us/step - loss: 1.6452 - accuracy: 0.4711 - val_loss: 1.6603 - val_accuracy: 0.4627
# Epoch 9/50
# 50000/50000 [==============================] - 18s 363us/step - loss: 1.6181 - accuracy: 0.4821 - val_loss: 1.6813 - val_accuracy: 0.4554
# Epoch 10/50
# 50000/50000 [==============================] - 18s 360us/step - loss: 1.5931 - accuracy: 0.4885 - val_loss: 1.6222 - val_accuracy: 0.4725
# Epoch 11/50
# 50000/50000 [==============================] - 18s 361us/step - loss: 1.5692 - accuracy: 0.4981 - val_loss: 1.6095 - val_accuracy: 0.4806
# Epoch 12/50
# 50000/50000 [==============================] - 18s 365us/step - loss: 1.5482 - accuracy: 0.5060 - val_loss: 1.5858 - val_accuracy: 0.4870
# Epoch 13/50
# 50000/50000 [==============================] - 18s 365us/step - loss: 1.5293 - accuracy: 0.5093 - val_loss: 1.5930 - val_accuracy: 0.4842
# Epoch 14/50
# 50000/50000 [==============================] - 19s 380us/step - loss: 1.5090 - accuracy: 0.5167 - val_loss: 1.5649 - val_accuracy: 0.4966
# Epoch 15/50
# 50000/50000 [==============================] - 19s 383us/step - loss: 1.4891 - accuracy: 0.5239 - val_loss: 1.5533 - val_accuracy: 0.5017
# Epoch 16/50
# 50000/50000 [==============================] - 19s 375us/step - loss: 1.4728 - accuracy: 0.5314 - val_loss: 1.5765 - val_accuracy: 0.4958
# Epoch 17/50
# 50000/50000 [==============================] - 18s 362us/step - loss: 1.4545 - accuracy: 0.5364 - val_loss: 1.5596 - val_accuracy: 0.4964
# Epoch 18/50
# 50000/50000 [==============================] - 18s 358us/step - loss: 1.4390 - accuracy: 0.5413 - val_loss: 1.5426 - val_accuracy: 0.5049
# Epoch 19/50
# 50000/50000 [==============================] - 18s 363us/step - loss: 1.4187 - accuracy: 0.5486 - val_loss: 1.5328 - val_accuracy: 0.5027
# Epoch 20/50
# 50000/50000 [==============================] - 19s 371us/step - loss: 1.4037 - accuracy: 0.5548 - val_loss: 1.5190 - val_accuracy: 0.5081
# Epoch 21/50
# 50000/50000 [==============================] - 18s 363us/step - loss: 1.3873 - accuracy: 0.5619 - val_loss: 1.5131 - val_accuracy: 0.5145
# Epoch 22/50
# 50000/50000 [==============================] - 18s 362us/step - loss: 1.3751 - accuracy: 0.5641 - val_loss: 1.5445 - val_accuracy: 0.5023
# Epoch 23/50
# 50000/50000 [==============================] - 19s 382us/step - loss: 1.3607 - accuracy: 0.5698 - val_loss: 1.5033 - val_accuracy: 0.5178
# Epoch 24/50
# 50000/50000 [==============================] - 20s 397us/step - loss: 1.3422 - accuracy: 0.5761 - val_loss: 1.4965 - val_accuracy: 0.5193
# Epoch 25/50
# 50000/50000 [==============================] - 19s 373us/step - loss: 1.3283 - accuracy: 0.5818 - val_loss: 1.4996 - val_accuracy: 0.5171
# Epoch 26/50
# 50000/50000 [==============================] - 19s 384us/step - loss: 1.3146 - accuracy: 0.5848 - val_loss: 1.4878 - val_accuracy: 0.5192
# Epoch 27/50
# 50000/50000 [==============================] - 19s 382us/step - loss: 1.2999 - accuracy: 0.5919 - val_loss: 1.4747 - val_accuracy: 0.5294
# Epoch 28/50
# 50000/50000 [==============================] - 18s 365us/step - loss: 1.2906 - accuracy: 0.5939 - val_loss: 1.6151 - val_accuracy: 0.4922
# Epoch 29/50
# 50000/50000 [==============================] - 18s 361us/step - loss: 1.2757 - accuracy: 0.5997 - val_loss: 1.4955 - val_accuracy: 0.5215
# Epoch 30/50
# 50000/50000 [==============================] - 19s 376us/step - loss: 1.2586 - accuracy: 0.6066 - val_loss: 1.5437 - val_accuracy: 0.5113
# Epoch 31/50
# 50000/50000 [==============================] - 18s 364us/step - loss: 1.2491 - accuracy: 0.6101 - val_loss: 1.5437 - val_accuracy: 0.5111
# Epoch 32/50
# 50000/50000 [==============================] - 18s 365us/step - loss: 1.2376 - accuracy: 0.6153 - val_loss: 1.6373 - val_accuracy: 0.4871
# Epoch 33/50
# 50000/50000 [==============================] - 18s 366us/step - loss: 1.2235 - accuracy: 0.6194 - val_loss: 1.4896 - val_accuracy: 0.5324
# Epoch 34/50
# 50000/50000 [==============================] - 18s 363us/step - loss: 1.2087 - accuracy: 0.6249 - val_loss: 1.4971 - val_accuracy: 0.5231
# Epoch 35/50
# 50000/50000 [==============================] - 18s 366us/step - loss: 1.1981 - accuracy: 0.6281 - val_loss: 1.5269 - val_accuracy: 0.5163
# Epoch 36/50
# 50000/50000 [==============================] - 19s 374us/step - loss: 1.1848 - accuracy: 0.6313 - val_loss: 1.5174 - val_accuracy: 0.5246
# Epoch 37/50
# 50000/50000 [==============================] - 18s 369us/step - loss: 1.1717 - accuracy: 0.6377 - val_loss: 1.4801 - val_accuracy: 0.5361
# Epoch 38/50
# 50000/50000 [==============================] - 18s 369us/step - loss: 1.1614 - accuracy: 0.6409 - val_loss: 1.5003 - val_accuracy: 0.5249
# Epoch 39/50
# 50000/50000 [==============================] - 18s 367us/step - loss: 1.1479 - accuracy: 0.6478 - val_loss: 1.5635 - val_accuracy: 0.5124
# Epoch 40/50
# 50000/50000 [==============================] - 18s 368us/step - loss: 1.1425 - accuracy: 0.6453 - val_loss: 1.4731 - val_accuracy: 0.5368
# Epoch 41/50
# 50000/50000 [==============================] - 19s 372us/step - loss: 1.1198 - accuracy: 0.6567 - val_loss: 1.6486 - val_accuracy: 0.4967
# Epoch 42/50
# 50000/50000 [==============================] - 18s 367us/step - loss: 1.1122 - accuracy: 0.6582 - val_loss: 1.4923 - val_accuracy: 0.5350
# Epoch 43/50
# 50000/50000 [==============================] - 18s 365us/step - loss: 1.1019 - accuracy: 0.6614 - val_loss: 1.4904 - val_accuracy: 0.5360
# Epoch 44/50
# 50000/50000 [==============================] - 18s 365us/step - loss: 1.0884 - accuracy: 0.6690 - val_loss: 1.5379 - val_accuracy: 0.5226
# Epoch 45/50
# 50000/50000 [==============================] - 18s 362us/step - loss: 1.0699 - accuracy: 0.6760 - val_loss: 1.5156 - val_accuracy: 0.5355
# Epoch 46/50
# 50000/50000 [==============================] - 18s 360us/step - loss: 1.0650 - accuracy: 0.6770 - val_loss: 1.5020 - val_accuracy: 0.5380
# Epoch 47/50
# 50000/50000 [==============================] - 19s 373us/step - loss: 1.0520 - accuracy: 0.6817 - val_loss: 1.5398 - val_accuracy: 0.5277
# Epoch 48/50
# 50000/50000 [==============================] - 19s 379us/step - loss: 1.0388 - accuracy: 0.6879 - val_loss: 1.5535 - val_accuracy: 0.5275
# Epoch 49/50
# 50000/50000 [==============================] - 18s 362us/step - loss: 1.0297 - accuracy: 0.6913 - val_loss: 1.5150 - val_accuracy: 0.5351
# Epoch 50/50
# 50000/50000 [==============================] - 18s 353us/step - loss: 1.0175 - accuracy: 0.6933 - val_loss: 1.5776 - val_accuracy: 0.5218
# Experiment with Regulizer = 0.000000
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 19s 380us/step - loss: 2.0155 - accuracy: 0.2880 - val_loss: 1.8438 - val_accuracy: 0.3524
# Epoch 2/50
# 50000/50000 [==============================] - 19s 370us/step - loss: 1.7888 - accuracy: 0.3748 - val_loss: 1.7379 - val_accuracy: 0.3915
# Epoch 3/50
# 50000/50000 [==============================] - 18s 369us/step - loss: 1.7112 - accuracy: 0.4028 - val_loss: 1.6910 - val_accuracy: 0.4010
# Epoch 4/50
# 50000/50000 [==============================] - 18s 361us/step - loss: 1.6564 - accuracy: 0.4217 - val_loss: 1.6319 - val_accuracy: 0.4273
# Epoch 5/50
# 50000/50000 [==============================] - 18s 368us/step - loss: 1.6096 - accuracy: 0.4384 - val_loss: 1.6002 - val_accuracy: 0.4384
# Epoch 6/50
# 50000/50000 [==============================] - 18s 365us/step - loss: 1.5711 - accuracy: 0.4514 - val_loss: 1.5680 - val_accuracy: 0.4478
# Epoch 7/50
# 50000/50000 [==============================] - 18s 367us/step - loss: 1.5367 - accuracy: 0.4624 - val_loss: 1.5596 - val_accuracy: 0.4457
# Epoch 8/50
# 50000/50000 [==============================] - 18s 364us/step - loss: 1.5072 - accuracy: 0.4728 - val_loss: 1.5193 - val_accuracy: 0.4657
# Epoch 9/50
# 50000/50000 [==============================] - 18s 360us/step - loss: 1.4814 - accuracy: 0.4834 - val_loss: 1.5163 - val_accuracy: 0.4602
# Epoch 10/50
# 50000/50000 [==============================] - 20s 393us/step - loss: 1.4545 - accuracy: 0.4897 - val_loss: 1.4894 - val_accuracy: 0.4685
# Epoch 11/50
# 50000/50000 [==============================] - 18s 364us/step - loss: 1.4299 - accuracy: 0.4988 - val_loss: 1.4803 - val_accuracy: 0.4779
# Epoch 12/50
# 50000/50000 [==============================] - 19s 372us/step - loss: 1.4063 - accuracy: 0.5062 - val_loss: 1.4590 - val_accuracy: 0.4803
# Epoch 13/50
# 50000/50000 [==============================] - 18s 362us/step - loss: 1.3843 - accuracy: 0.5144 - val_loss: 1.4451 - val_accuracy: 0.4934
# Epoch 14/50
# 50000/50000 [==============================] - 18s 366us/step - loss: 1.3654 - accuracy: 0.5212 - val_loss: 1.4433 - val_accuracy: 0.4914
# Epoch 15/50
# 50000/50000 [==============================] - 18s 363us/step - loss: 1.3436 - accuracy: 0.5272 - val_loss: 1.4212 - val_accuracy: 0.4991
# Epoch 16/50
# 50000/50000 [==============================] - 18s 366us/step - loss: 1.3244 - accuracy: 0.5352 - val_loss: 1.4402 - val_accuracy: 0.4953
# Epoch 17/50
# 50000/50000 [==============================] - 18s 364us/step - loss: 1.3076 - accuracy: 0.5410 - val_loss: 1.4006 - val_accuracy: 0.5038
# Epoch 18/50
# 50000/50000 [==============================] - 18s 361us/step - loss: 1.2908 - accuracy: 0.5465 - val_loss: 1.3943 - val_accuracy: 0.5068
# Epoch 19/50
# 50000/50000 [==============================] - 18s 368us/step - loss: 1.2715 - accuracy: 0.5529 - val_loss: 1.4175 - val_accuracy: 0.4943
# Epoch 20/50
# 50000/50000 [==============================] - 18s 369us/step - loss: 1.2559 - accuracy: 0.5595 - val_loss: 1.3727 - val_accuracy: 0.5108
# Epoch 21/50
# 50000/50000 [==============================] - 18s 364us/step - loss: 1.2406 - accuracy: 0.5634 - val_loss: 1.3909 - val_accuracy: 0.5065
# Epoch 22/50
# 50000/50000 [==============================] - 19s 372us/step - loss: 1.2239 - accuracy: 0.5695 - val_loss: 1.3631 - val_accuracy: 0.5189
# Epoch 23/50
# 50000/50000 [==============================] - 18s 361us/step - loss: 1.2103 - accuracy: 0.5742 - val_loss: 1.3579 - val_accuracy: 0.5210
# Epoch 24/50
# 50000/50000 [==============================] - 18s 365us/step - loss: 1.1965 - accuracy: 0.5801 - val_loss: 1.3667 - val_accuracy: 0.5148
# Epoch 25/50
# 50000/50000 [==============================] - 18s 360us/step - loss: 1.1810 - accuracy: 0.5847 - val_loss: 1.3618 - val_accuracy: 0.5148
# Epoch 26/50
# 50000/50000 [==============================] - 18s 363us/step - loss: 1.1679 - accuracy: 0.5917 - val_loss: 1.3459 - val_accuracy: 0.5231
# Epoch 27/50
# 50000/50000 [==============================] - 18s 362us/step - loss: 1.1539 - accuracy: 0.5941 - val_loss: 1.4798 - val_accuracy: 0.4847
# Epoch 28/50
# 50000/50000 [==============================] - 18s 366us/step - loss: 1.1404 - accuracy: 0.5999 - val_loss: 1.4038 - val_accuracy: 0.5119
# Epoch 29/50
# 50000/50000 [==============================] - 18s 370us/step - loss: 1.1226 - accuracy: 0.6061 - val_loss: 1.3880 - val_accuracy: 0.5136
# Epoch 30/50
# 50000/50000 [==============================] - 19s 384us/step - loss: 1.1116 - accuracy: 0.6099 - val_loss: 1.3423 - val_accuracy: 0.5258
# Epoch 31/50
# 50000/50000 [==============================] - 19s 376us/step - loss: 1.0997 - accuracy: 0.6145 - val_loss: 1.3296 - val_accuracy: 0.5318
# Epoch 32/50
# 50000/50000 [==============================] - 18s 369us/step - loss: 1.0855 - accuracy: 0.6183 - val_loss: 1.3417 - val_accuracy: 0.5355
# Epoch 33/50
# 50000/50000 [==============================] - 19s 371us/step - loss: 1.0745 - accuracy: 0.6246 - val_loss: 1.3895 - val_accuracy: 0.5151
# Epoch 34/50
# 50000/50000 [==============================] - 19s 381us/step - loss: 1.0590 - accuracy: 0.6283 - val_loss: 1.4872 - val_accuracy: 0.4904
# Epoch 35/50
# 50000/50000 [==============================] - 19s 376us/step - loss: 1.0478 - accuracy: 0.6314 - val_loss: 1.3496 - val_accuracy: 0.5292
# Epoch 36/50
# 50000/50000 [==============================] - 19s 381us/step - loss: 1.0346 - accuracy: 0.6362 - val_loss: 1.3275 - val_accuracy: 0.5400
# Epoch 37/50
# 50000/50000 [==============================] - 19s 375us/step - loss: 1.0230 - accuracy: 0.6382 - val_loss: 1.3788 - val_accuracy: 0.5224
# Epoch 38/50
# 50000/50000 [==============================] - 19s 372us/step - loss: 1.0100 - accuracy: 0.6448 - val_loss: 1.5703 - val_accuracy: 0.4857
# Epoch 39/50
# 50000/50000 [==============================] - 19s 371us/step - loss: 0.9930 - accuracy: 0.6513 - val_loss: 1.4073 - val_accuracy: 0.5187
# Epoch 40/50
# 50000/50000 [==============================] - 19s 379us/step - loss: 0.9875 - accuracy: 0.6526 - val_loss: 1.3607 - val_accuracy: 0.5338
# Epoch 41/50
# 50000/50000 [==============================] - 18s 367us/step - loss: 0.9704 - accuracy: 0.6589 - val_loss: 1.3993 - val_accuracy: 0.5210
# Epoch 42/50
# 50000/50000 [==============================] - 18s 370us/step - loss: 0.9558 - accuracy: 0.6632 - val_loss: 1.3649 - val_accuracy: 0.5331
# Epoch 43/50
# 50000/50000 [==============================] - 19s 381us/step - loss: 0.9446 - accuracy: 0.6695 - val_loss: 1.4419 - val_accuracy: 0.5137
# Epoch 44/50
# 50000/50000 [==============================] - 20s 394us/step - loss: 0.9347 - accuracy: 0.6715 - val_loss: 1.3882 - val_accuracy: 0.5355
# Epoch 45/50
# 50000/50000 [==============================] - 19s 377us/step - loss: 0.9195 - accuracy: 0.6761 - val_loss: 1.3797 - val_accuracy: 0.5260
# Epoch 46/50
# 50000/50000 [==============================] - 18s 365us/step - loss: 0.9099 - accuracy: 0.6812 - val_loss: 1.3959 - val_accuracy: 0.5299
# Epoch 47/50
# 50000/50000 [==============================] - 18s 366us/step - loss: 0.8983 - accuracy: 0.6853 - val_loss: 1.4337 - val_accuracy: 0.5261
# Epoch 48/50
# 50000/50000 [==============================] - 18s 369us/step - loss: 0.8880 - accuracy: 0.6893 - val_loss: 1.3776 - val_accuracy: 0.5330
# Epoch 49/50
# 50000/50000 [==============================] - 18s 367us/step - loss: 0.8758 - accuracy: 0.6929 - val_loss: 1.5304 - val_accuracy: 0.5028
# Epoch 50/50
# 50000/50000 [==============================] - 18s 369us/step - loss: 0.8642 - accuracy: 0.6973 - val_loss: 1.4018 - val_accuracy: 0.5320
# Experiment with Regulizer = 0.000000
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 20s 396us/step - loss: 2.0309 - accuracy: 0.2738 - val_loss: 1.8685 - val_accuracy: 0.3389
# Epoch 2/50
# 50000/50000 [==============================] - 19s 378us/step - loss: 1.8127 - accuracy: 0.3627 - val_loss: 1.7650 - val_accuracy: 0.3811
# Epoch 3/50
# 50000/50000 [==============================] - 19s 371us/step - loss: 1.7299 - accuracy: 0.3919 - val_loss: 1.7021 - val_accuracy: 0.4056
# Epoch 4/50
# 50000/50000 [==============================] - 19s 378us/step - loss: 1.6719 - accuracy: 0.4142 - val_loss: 1.6435 - val_accuracy: 0.4248
# Epoch 5/50
# 50000/50000 [==============================] - 19s 377us/step - loss: 1.6254 - accuracy: 0.4308 - val_loss: 1.6089 - val_accuracy: 0.4357
# Epoch 6/50
# 50000/50000 [==============================] - 19s 378us/step - loss: 1.5869 - accuracy: 0.4445 - val_loss: 1.5825 - val_accuracy: 0.4456
# Epoch 7/50
# 50000/50000 [==============================] - 19s 376us/step - loss: 1.5536 - accuracy: 0.4567 - val_loss: 1.5489 - val_accuracy: 0.4564
# Epoch 8/50
# 50000/50000 [==============================] - 19s 377us/step - loss: 1.5237 - accuracy: 0.4671 - val_loss: 1.5301 - val_accuracy: 0.4603
# Epoch 9/50
# 50000/50000 [==============================] - 19s 377us/step - loss: 1.4975 - accuracy: 0.4762 - val_loss: 1.5413 - val_accuracy: 0.4565
# Epoch 10/50
# 50000/50000 [==============================] - 19s 376us/step - loss: 1.4719 - accuracy: 0.4836 - val_loss: 1.4981 - val_accuracy: 0.4721
# Epoch 11/50
# 50000/50000 [==============================] - 19s 380us/step - loss: 1.4481 - accuracy: 0.4923 - val_loss: 1.4765 - val_accuracy: 0.4776
# Epoch 12/50
# 50000/50000 [==============================] - 19s 375us/step - loss: 1.4253 - accuracy: 0.4989 - val_loss: 1.5105 - val_accuracy: 0.4652
# Epoch 13/50
# 50000/50000 [==============================] - 19s 380us/step - loss: 1.4042 - accuracy: 0.5090 - val_loss: 1.4558 - val_accuracy: 0.4803
# Epoch 14/50
# 50000/50000 [==============================] - 19s 382us/step - loss: 1.3820 - accuracy: 0.5167 - val_loss: 1.4388 - val_accuracy: 0.4909
# Epoch 15/50
# 50000/50000 [==============================] - 19s 374us/step - loss: 1.3637 - accuracy: 0.5204 - val_loss: 1.4298 - val_accuracy: 0.4957
# Epoch 16/50
# 50000/50000 [==============================] - 19s 383us/step - loss: 1.3434 - accuracy: 0.5295 - val_loss: 1.4085 - val_accuracy: 0.4995
# Epoch 17/50
# 50000/50000 [==============================] - 19s 385us/step - loss: 1.3264 - accuracy: 0.5353 - val_loss: 1.4001 - val_accuracy: 0.5056
# Epoch 18/50
# 50000/50000 [==============================] - 19s 378us/step - loss: 1.3084 - accuracy: 0.5423 - val_loss: 1.4106 - val_accuracy: 0.5003
# Epoch 19/50
# 50000/50000 [==============================] - 19s 376us/step - loss: 1.2910 - accuracy: 0.5458 - val_loss: 1.3879 - val_accuracy: 0.5094
# Epoch 20/50
# 50000/50000 [==============================] - 19s 376us/step - loss: 1.2742 - accuracy: 0.5515 - val_loss: 1.4253 - val_accuracy: 0.5032
# Epoch 21/50
# 50000/50000 [==============================] - 19s 386us/step - loss: 1.2603 - accuracy: 0.5563 - val_loss: 1.3762 - val_accuracy: 0.5129
# Epoch 22/50
# 50000/50000 [==============================] - 19s 377us/step - loss: 1.2457 - accuracy: 0.5614 - val_loss: 1.3665 - val_accuracy: 0.5174
# Epoch 23/50
# 50000/50000 [==============================] - 19s 379us/step - loss: 1.2284 - accuracy: 0.5674 - val_loss: 1.3734 - val_accuracy: 0.5140
# Epoch 24/50
# 50000/50000 [==============================] - 19s 379us/step - loss: 1.2141 - accuracy: 0.5728 - val_loss: 1.3695 - val_accuracy: 0.5183
# Epoch 25/50
# 50000/50000 [==============================] - 19s 376us/step - loss: 1.1970 - accuracy: 0.5783 - val_loss: 1.3935 - val_accuracy: 0.5156
# Epoch 26/50
# 50000/50000 [==============================] - 21s 411us/step - loss: 1.1859 - accuracy: 0.5826 - val_loss: 1.3888 - val_accuracy: 0.5125
# Epoch 27/50
# 50000/50000 [==============================] - 20s 393us/step - loss: 1.1691 - accuracy: 0.5890 - val_loss: 1.4154 - val_accuracy: 0.5048
# Epoch 28/50
# 50000/50000 [==============================] - 19s 382us/step - loss: 1.1578 - accuracy: 0.5937 - val_loss: 1.3505 - val_accuracy: 0.5145
# Epoch 29/50
# 50000/50000 [==============================] - 19s 378us/step - loss: 1.1440 - accuracy: 0.5969 - val_loss: 1.3456 - val_accuracy: 0.5197
# Epoch 30/50
# 50000/50000 [==============================] - 19s 387us/step - loss: 1.1314 - accuracy: 0.6017 - val_loss: 1.3363 - val_accuracy: 0.5313
# Epoch 31/50
# 50000/50000 [==============================] - 19s 382us/step - loss: 1.1194 - accuracy: 0.6059 - val_loss: 1.3575 - val_accuracy: 0.5188
# Epoch 32/50
# 50000/50000 [==============================] - 19s 385us/step - loss: 1.1056 - accuracy: 0.6117 - val_loss: 1.3759 - val_accuracy: 0.5271
# Epoch 33/50
# 50000/50000 [==============================] - 19s 384us/step - loss: 1.0916 - accuracy: 0.6178 - val_loss: 1.3442 - val_accuracy: 0.5280
# Epoch 34/50
# 50000/50000 [==============================] - 19s 379us/step - loss: 1.0773 - accuracy: 0.6224 - val_loss: 1.3895 - val_accuracy: 0.5221
# Epoch 35/50
# 50000/50000 [==============================] - 19s 378us/step - loss: 1.0635 - accuracy: 0.6273 - val_loss: 1.3420 - val_accuracy: 0.5302
# Epoch 36/50
# 50000/50000 [==============================] - 19s 384us/step - loss: 1.0537 - accuracy: 0.6291 - val_loss: 1.3668 - val_accuracy: 0.5194
# Epoch 37/50
# 50000/50000 [==============================] - 19s 380us/step - loss: 1.0427 - accuracy: 0.6337 - val_loss: 1.3430 - val_accuracy: 0.5300
# Epoch 38/50
# 50000/50000 [==============================] - 19s 378us/step - loss: 1.0289 - accuracy: 0.6372 - val_loss: 1.3480 - val_accuracy: 0.5338
# Epoch 39/50
# 50000/50000 [==============================] - 19s 376us/step - loss: 1.0155 - accuracy: 0.6423 - val_loss: 1.3498 - val_accuracy: 0.5246
# Epoch 40/50
# 50000/50000 [==============================] - 19s 372us/step - loss: 1.0059 - accuracy: 0.6470 - val_loss: 1.3754 - val_accuracy: 0.5288
# Epoch 41/50
# 50000/50000 [==============================] - 18s 369us/step - loss: 0.9893 - accuracy: 0.6551 - val_loss: 1.3690 - val_accuracy: 0.5333
# Epoch 42/50
# 50000/50000 [==============================] - 19s 375us/step - loss: 0.9772 - accuracy: 0.6561 - val_loss: 1.3517 - val_accuracy: 0.5320
# Epoch 43/50
# 50000/50000 [==============================] - 19s 378us/step - loss: 0.9658 - accuracy: 0.6611 - val_loss: 1.3633 - val_accuracy: 0.5303
# Epoch 44/50
# 50000/50000 [==============================] - 20s 390us/step - loss: 0.9531 - accuracy: 0.6653 - val_loss: 1.3498 - val_accuracy: 0.5321
# Epoch 45/50
# 50000/50000 [==============================] - 19s 384us/step - loss: 0.9384 - accuracy: 0.6716 - val_loss: 1.3523 - val_accuracy: 0.5379
# Epoch 46/50
# 50000/50000 [==============================] - 18s 370us/step - loss: 0.9263 - accuracy: 0.6771 - val_loss: 1.3811 - val_accuracy: 0.5325
# Epoch 47/50
# 50000/50000 [==============================] - 19s 375us/step - loss: 0.9167 - accuracy: 0.6796 - val_loss: 1.4720 - val_accuracy: 0.5064
# Epoch 48/50
# 50000/50000 [==============================] - 19s 381us/step - loss: 0.9091 - accuracy: 0.6806 - val_loss: 1.4020 - val_accuracy: 0.5271
# Epoch 49/50
# 50000/50000 [==============================] - 19s 377us/step - loss: 0.8935 - accuracy: 0.6881 - val_loss: 1.3729 - val_accuracy: 0.5411
# Epoch 50/50
# 50000/50000 [==============================] - 19s 381us/step - loss: 0.8819 - accuracy: 0.6927 - val_loss: 1.4405 - val_accuracy: 0.5254

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""
color_bar = ["r", "g", "b", "y", "m", "k"]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.ylim([0, 5])
plt.legend()
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend()
plt.show()
